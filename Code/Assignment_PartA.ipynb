# %% [markdown]
# #### Import Libraries

# %%
# !pip install pandas
# !pip install pymongo
# !pip install pprint
import pandas as pd
import pprint
from datetime import datetime
import re
import pymongo
from pymongo import MongoClient

# %% [markdown]
# #### Read CSVs

# %%
climate_historic = pd.read_csv('../Datasets/climate_historic.csv')
hotspot_historic = pd.read_csv('../Datasets/hotspot_historic.csv')

# %%
climate_historic.head()
# Out:
#    station        date  air_temperature_celcius  relative_humidity  \
# 0   948700  31/12/2021                       19               56.8
# 1   948700    2/1/2022                       15               50.7
# 2   948700    3/1/2022                       16               53.6
# 3   948700    4/1/2022                       24               61.6
# 4   948700    5/1/2022                       24               62.3
#
#    windspeed_knots  max_wind_speed precipitation   GHI_w/m2
# 0              7.9            11.1          0.00I       154
# 1              9.2            13.0          0.02G       128
# 2              8.1            15.0          0.00G       133
# 3              7.7            14.0          0.00I       186
# 4              7.0            13.0          0.00I       185

# %%
hotspot_historic.head()
# Out:
#    latitude  longitude             datetime  confidence        date  \
# 0   -37.966    145.051  2022-12-27T04:16:51          78  27/12/2022
# 1   -35.541    143.311  2022-12-27T00:02:15          82  27/12/2022
# 2   -35.554    143.307  2022-12-27T00:02:15          67  27/12/2022
# 3   -35.543    143.316  2022-12-27T00:02:14          86  27/12/2022
# 4   -37.708    145.100  2022-12-25T04:29:08          80  25/12/2022
#
#    surface_temperature_celcius
# 0                           68
# 1                           63
# 2                           53
# 3                           67
# 4                           54

# %% [markdown]
# Based on the two data sets provided i.e. hotspot_historic.csv and climate_historic.csv, design a suitable data model to support the efficient querying of the two data sets in MongoDB. Justify your data model design.
# The output of this task should be
# - An example of the data model.
# - The justification for choosing that data model.

# %% [markdown]
# ## Data Model
# Based on the two datasets given, embedded document seems to be best choice as we can embed hotspot data within the climate data. Climate data contain document a day, while hotspot data can have more than 1 document a day. It will make a lot of sense, to have multiple hotspot embedded into climate data due to several reason:
#
# 1. Simplicity: Embedded data are easier to understand and work with. All the relevant and related data is stored within one document instead of spread out across multiple documents. This make query and manipulation on the data cleaner and simpler.
# 2. Performance: Embedded can provide better time performance in certain situation, especially when data are regularly accessed together. Since, all the relevant and related data is stored within one document, query such as update and join will be much faster as we don't have to reference multiple documents.
# 3. Atomicity: Embedded data allow for operation on single document. When deleting, updating or modifying a document, we only need to perform the operation on one document instead of multiple referenced document. This is a property of atomicity.

# %% [markdown]
# #### Example of Embedded Document

# %%
"""
{
    _id: ObjectId("64806e495dfd959c2ee65a26"),
    date: '2021-12-31T00:00:00.000Z',
    station: 948700,
    air_temperature: 19,
    relative_humidity: 56.8,
    windspeed_knots: 7.9,
    max_wind_speed: 11.1,
    precipitation: 0,
    precipitation_flag: 'I',
    GHI: 154,
    hotspot: [
      {
        datetime: '2021-12-31T04:42:00.000Z',
        hotspot_latitude: -37.3803,
        hotspot_longitude: 145.611,
        confidence: 91,
        surface_temperature: 68
      },
      {
        datetime: '2021-12-31T03:55:00.000Z',
        hotspot_latitude: -36.4355,
        hotspot_longitude: 141.5901,
        confidence: 72,
        surface_temperature: 46
      },
    ]
}
""";

# %% [markdown]
# ## Task 2.1 - Load Data From CSVs Into MongoDB

# %%
# Specify host and port
ip_address = '192.168.0.221' # Change the ip_adress to host
client = MongoClient(ip_address, 27017)

# %%
# Using A3_db
db = client['A3_db'] 

# Using collection fire_historic
fire_collection = db['fire_historic'] # Collection of Climate Historic and Hotspot Historic (embedded)

# fire_collection.drop()

# %%
# Function to turn string into ISO date
def date_to_iso(date, date_format='%d/%m/%Y'):
    return datetime.strptime(str(date), date_format)

# Map function to value, if error is raised return None
# If value is classified as null also return None
def val_or_null(value, func, null=None):
    try:
        value = func(value)
        if value == null:
            return None
        else:
            return value
    except:
        return None

# %%
# Parse Climate Historic
for index, row in climate_historic.iterrows():
    date = date_to_iso(row.date)
    precipitation = str(row['precipitation ']).strip()
    p = re.match(r'([0-9.]+)([a-z]+)', precipitation, re.I)

    if p:
        p = p.groups()
        precipitation_flag = p[1]
        precipitation = float(p[0])
    
    station = val_or_null(row.station, int)
    air_temperature = val_or_null(row.air_temperature_celcius, float)
    relative_humidity = val_or_null(row.relative_humidity, float)
    windspeed_knots = val_or_null(row.windspeed_knots, float)
    max_wind_speed = val_or_null(row.max_wind_speed, float)
    GHI = val_or_null(row['GHI_w/m2'], float)

    document = {
        'station' : station,
        'date' : date,
        'hotspot':[],
        'air_temperature': air_temperature,
        'relative_humidity': relative_humidity,
        'windspeed_knots': windspeed_knots,
        'max_wind_speed': max_wind_speed,
        'precipitation_flag': precipitation_flag,
        'precipitation': precipitation,
        'GHI' : GHI
    }
    
    fire_collection.insert_one(document)

# %%
# Parse Hotspot Historic
for index, row in hotspot_historic.iterrows():
    latitude = val_or_null(row.latitude, float)
    longitude = val_or_null(row.longitude, float)
    dtime = val_or_null(row.datetime, lambda x: datetime.fromisoformat(str(x)))
    confidence = val_or_null(row.confidence, float)
    date = val_or_null(row.date, date_to_iso)
    surface_temperature = val_or_null(row.surface_temperature_celcius, float)


    document = {
#         'location': {'type': 'Point', 'coordinates': [longitude, latitude]}, # Store longitude and latitude as location
        'longitude': longitude,
        'latitude': latitude,
        'datetime': dtime, 
        'confidence': confidence,
        'surface_temperature': surface_temperature
    }
    
    fire_collection.update_one({'date':date}, {'$push':{'hotspot':document}}, upsert=True)

# %% [markdown]
# ## Task 2.2 - Writing Queries

# %%
# Function for printing query
def print_response(response):
    for res in response:
        pprint.pp(res)
        print()

# %% [markdown]
# a) Find climate data on 12th December 2022.

# %%
response = fire_collection.find({'date':date_to_iso('12/12/2022')})

# %%
print_response(response)
# Out:
# {'_id': ObjectId('64809eaa99470914613da023'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 12, 12, 0, 0),
#  'hotspot': [{'longitude': 145.25,
#               'latitude': -37.903,
#               'datetime': datetime.datetime(2022, 12, 12, 0, 45, 38),
#               'confidence': 53.0,
#               'surface_temperature': 44.0}],
#  'air_temperature': 19.0,
#  'relative_humidity': 55.3,
#  'windspeed_knots': 6.2,
#  'max_wind_speed': 12.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 156.0}

# %% [markdown]
# b) Find the latitude, longitude, surface temperature (°C), and confidence when the surface temperature (°C) was between 65 °C and 100 °C.

# %%
response = fire_collection.aggregate([
    {'$unwind':'$hotspot'},
    {'$match':{
        'hotspot.surface_temperature':{'$gte':65, '$lte':100}
    }},
    {'$project':{'_id':0, 
                 'hotspot.latitude':1, 
                 'hotspot.longitude':1, 
                 'hotspot.surface_temperature':1,
                 'hotspot.confidence':1
                }}
]
)

# %%
print_response(response)
# Out:
# {'hotspot': {'longitude': 147.9187,
#              'latitude': -37.2284,
#              'confidence': 94.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 142.0703,
#              'latitude': -37.6572,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 148.1459,
#              'latitude': -37.0193,
#              'confidence': 84.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 147.027,
#              'latitude': -37.4229,
#              'confidence': 100.0,
#              'surface_temperature': 99.0}}
#
# {'hotspot': {'longitude': 148.1582,
#              'latitude': -37.0055,
#              'confidence': 80.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 147.0242,
#              'latitude': -37.4128,
#              'confidence': 85.0,
#              'surface_temperature': 98.0}}
#
# {'hotspot': {'longitude': 141.5361,
#              'latitude': -34.357,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 141.5547,
#              'latitude': -34.3539,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 148.2244,
#              'latitude': -36.9939,
#              'confidence': 90.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 148.2118,
#              'latitude': -36.9959,
#              'confidence': 95.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 141.543,
#              'latitude': -34.3654,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.5413,
#              'latitude': -34.3554,
#              'confidence': 96.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 141.5495,
#              'latitude': -34.3555,
#              'confidence': 94.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 141.3853,
#              'latitude': -36.7152,
#              'confidence': 94.0,
#              'surface_temperature': 74.0}}
#
# {'hotspot': {'longitude': 148.1432,
#              'latitude': -37.0155,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 142.1001,
#              'latitude': -37.6622,
#              'confidence': 96.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 147.0175,
#              'latitude': -37.4523,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 147.0323,
#              'latitude': -37.4261,
#              'confidence': 98.0,
#              'surface_temperature': 83.0}}
#
# {'hotspot': {'longitude': 147.0175,
#              'latitude': -37.3949,
#              'confidence': 100.0,
#              'surface_temperature': 91.0}}
#
# {'hotspot': {'longitude': 144.287,
#              'latitude': -37.6625,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 143.4754,
#              'latitude': -37.8973,
#              'confidence': 82.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 143.5003,
#              'latitude': -37.7805,
#              'confidence': 95.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 145.8213,
#              'latitude': -37.8774,
#              'confidence': 95.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 145.8229,
#              'latitude': -37.8881,
#              'confidence': 100.0,
#              'surface_temperature': 99.0}}
#
# {'hotspot': {'longitude': 143.3874,
#              'latitude': -37.522,
#              'confidence': 71.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 142.965,
#              'latitude': -38.0674,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 142.9591,
#              'latitude': -38.0715,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 142.9722,
#              'latitude': -38.0693,
#              'confidence': 100.0,
#              'surface_temperature': 89.0}}
#
# {'hotspot': {'longitude': 142.2434,
#              'latitude': -36.4557,
#              'confidence': 92.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 142.7259,
#              'latitude': -36.8009,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 142.728,
#              'latitude': -36.8099,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 141.5597,
#              'latitude': -36.7806,
#              'confidence': 94.0,
#              'surface_temperature': 74.0}}
#
# {'hotspot': {'longitude': 141.6458,
#              'latitude': -34.3526,
#              'confidence': 98.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 141.897,
#              'latitude': -37.0924,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 143.5834,
#              'latitude': -37.9452,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 141.6567,
#              'latitude': -34.351,
#              'confidence': 99.0,
#              'surface_temperature': 86.0}}
#
# {'hotspot': {'longitude': 142.5853,
#              'latitude': -37.5012,
#              'confidence': 100.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 142.8999,
#              'latitude': -37.9247,
#              'confidence': 97.0,
#              'surface_temperature': 81.0}}
#
# {'hotspot': {'longitude': 142.4642,
#              'latitude': -35.0805,
#              'confidence': 97.0,
#              'surface_temperature': 81.0}}
#
# {'hotspot': {'longitude': 145.886,
#              'latitude': -37.3735,
#              'confidence': 87.0,
#              'surface_temperature': 96.0}}
#
# {'hotspot': {'longitude': 143.3806,
#              'latitude': -37.7465,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 145.9738,
#              'latitude': -37.8072,
#              'confidence': 95.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 145.8942,
#              'latitude': -37.3704,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 143.5753,
#              'latitude': -37.297,
#              'confidence': 100.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 143.5487,
#              'latitude': -37.2988,
#              'confidence': 100.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 143.5714,
#              'latitude': -37.3025,
#              'confidence': 100.0,
#              'surface_temperature': 98.0}}
#
# {'hotspot': {'longitude': 145.9089,
#              'latitude': -37.383,
#              'confidence': 100.0,
#              'surface_temperature': 89.0}}
#
# {'hotspot': {'longitude': 143.4085,
#              'latitude': -37.7446,
#              'confidence': 89.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 143.4023,
#              'latitude': -37.7509,
#              'confidence': 98.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 145.9535,
#              'latitude': -37.7974,
#              'confidence': 87.0,
#              'surface_temperature': 97.0}}
#
# {'hotspot': {'longitude': 142.0906,
#              'latitude': -35.7657,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 143.3995,
#              'latitude': -37.7236,
#              'confidence': 99.0,
#              'surface_temperature': 86.0}}
#
# {'hotspot': {'longitude': 143.5448,
#              'latitude': -37.3046,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 141.2064,
#              'latitude': -36.4312,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 141.5904,
#              'latitude': -36.1556,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 142.0858,
#              'latitude': -35.7647,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 143.267,
#              'latitude': -35.4033,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 142.4349,
#              'latitude': -36.6281,
#              'confidence': 64.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 145.124,
#              'latitude': -36.111,
#              'confidence': 85.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 141.8728,
#              'latitude': -36.1615,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 142.1491,
#              'latitude': -36.1122,
#              'confidence': 90.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 145.8384,
#              'latitude': -37.3735,
#              'confidence': 100.0,
#              'surface_temperature': 95.0}}
#
# {'hotspot': {'longitude': 143.6306,
#              'latitude': -35.4255,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 145.914,
#              'latitude': -36.1955,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 143.2029,
#              'latitude': -35.4533,
#              'confidence': 85.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 141.9771,
#              'latitude': -36.5989,
#              'confidence': 92.0,
#              'surface_temperature': 81.0}}
#
# {'hotspot': {'longitude': 142.4234,
#              'latitude': -36.6299,
#              'confidence': 66.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 145.93,
#              'latitude': -36.1925,
#              'confidence': 97.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 141.7699,
#              'latitude': -36.095,
#              'confidence': 98.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 141.9657,
#              'latitude': -36.6006,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 141.042,
#              'latitude': -37.0769,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 142.1637,
#              'latitude': -36.883,
#              'confidence': 79.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 143.4279,
#              'latitude': -36.0973,
#              'confidence': 87.0,
#              'surface_temperature': 92.0}}
#
# {'hotspot': {'longitude': 145.9269,
#              'latitude': -36.1819,
#              'confidence': 100.0,
#              'surface_temperature': 98.0}}
#
# {'hotspot': {'longitude': 142.9032,
#              'latitude': -37.6387,
#              'confidence': 87.0,
#              'surface_temperature': 88.0}}
#
# {'hotspot': {'longitude': 142.913,
#              'latitude': -37.6439,
#              'confidence': 93.0,
#              'surface_temperature': 83.0}}
#
# {'hotspot': {'longitude': 147.4932,
#              'latitude': -37.3165,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 147.4986,
#              'latitude': -37.3158,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 147.6331,
#              'latitude': -37.4471,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 148.4138,
#              'latitude': -37.7835,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 147.6594,
#              'latitude': -37.4449,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 147.6583,
#              'latitude': -37.4323,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 147.6327,
#              'latitude': -37.4343,
#              'confidence': 100.0,
#              'surface_temperature': 92.0}}
#
# {'hotspot': {'longitude': 148.5862,
#              'latitude': -37.5816,
#              'confidence': 84.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 142.2244,
#              'latitude': -36.6334,
#              'confidence': 92.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 142.3196,
#              'latitude': -37.7966,
#              'confidence': 76.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 142.1326,
#              'latitude': -35.805,
#              'confidence': 100.0,
#              'surface_temperature': 95.0}}
#
# {'hotspot': {'longitude': 143.8366,
#              'latitude': -37.8429,
#              'confidence': 100.0,
#              'surface_temperature': 88.0}}
#
# {'hotspot': {'longitude': 143.3598,
#              'latitude': -37.8062,
#              'confidence': 77.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.8667,
#              'latitude': -36.9918,
#              'confidence': 100.0,
#              'surface_temperature': 97.0}}
#
# {'hotspot': {'longitude': 145.9829,
#              'latitude': -36.1104,
#              'confidence': 90.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 148.3844,
#              'latitude': -37.782,
#              'confidence': 100.0,
#              'surface_temperature': 99.0}}
#
# {'hotspot': {'longitude': 141.879,
#              'latitude': -36.9902,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 142.993,
#              'latitude': -37.745,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 145.9414,
#              'latitude': -36.0157,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 148.4128,
#              'latitude': -37.777,
#              'confidence': 99.0,
#              'surface_temperature': 85.0}}
#
# {'hotspot': {'longitude': 148.5949,
#              'latitude': -37.5888,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 141.7567,
#              'latitude': -34.3943,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.4934,
#              'latitude': -36.0844,
#              'confidence': 81.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 145.6824,
#              'latitude': -36.031,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 148.5777,
#              'latitude': -37.5814,
#              'confidence': 86.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 148.592,
#              'latitude': -37.5788,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 142.4075,
#              'latitude': -36.6384,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 142.1403,
#              'latitude': -35.811,
#              'confidence': 94.0,
#              'surface_temperature': 96.0}}
#
# {'hotspot': {'longitude': 141.0013,
#              'latitude': -36.9034,
#              'confidence': 100.0,
#              'surface_temperature': 95.0}}
#
# {'hotspot': {'longitude': 148.3673,
#              'latitude': -37.7746,
#              'confidence': 88.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 142.3151,
#              'latitude': -37.803,
#              'confidence': 83.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 142.9949,
#              'latitude': -37.7542,
#              'confidence': 96.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 145.611,
#              'latitude': -37.3803,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 143.081,
#              'latitude': -37.7617,
#              'confidence': 97.0,
#              'surface_temperature': 81.0}}
#
# {'hotspot': {'longitude': 142.9286,
#              'latitude': -37.8161,
#              'confidence': 92.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 145.6787,
#              'latitude': -36.0387,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 142.2125,
#              'latitude': -36.6349,
#              'confidence': 94.0,
#              'surface_temperature': 86.0}}
#
# {'hotspot': {'longitude': 141.0146,
#              'latitude': -36.9018,
#              'confidence': 100.0,
#              'surface_temperature': 100.0}}
#
# {'hotspot': {'longitude': 142.7259,
#              'latitude': -36.6986,
#              'confidence': 86.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 142.6179,
#              'latitude': -38.0052,
#              'confidence': 94.0,
#              'surface_temperature': 89.0}}
#
# {'hotspot': {'longitude': 147.4748,
#              'latitude': -37.2168,
#              'confidence': 100.0,
#              'surface_temperature': 89.0}}
#
# {'hotspot': {'longitude': 147.4689,
#              'latitude': -37.222,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 147.4713,
#              'latitude': -37.2063,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 147.4368,
#              'latitude': -37.2082,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 147.4347,
#              'latitude': -37.224,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 149.3668,
#              'latitude': -37.34,
#              'confidence': 67.0,
#              'surface_temperature': 74.0}}
#
# {'hotspot': {'longitude': 142.6017,
#              'latitude': -36.7287,
#              'confidence': 99.0,
#              'surface_temperature': 85.0}}
#
# {'hotspot': {'longitude': 143.0004,
#              'latitude': -35.2363,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 142.9864,
#              'latitude': -35.2378,
#              'confidence': 100.0,
#              'surface_temperature': 94.0}}
#
# {'hotspot': {'longitude': 142.994,
#              'latitude': -35.2381,
#              'confidence': 98.0,
#              'surface_temperature': 83.0}}
#
# {'hotspot': {'longitude': 149.3691,
#              'latitude': -37.3493,
#              'confidence': 66.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 142.6155,
#              'latitude': -36.7165,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 142.7374,
#              'latitude': -37.5812,
#              'confidence': 94.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 142.6857,
#              'latitude': -37.5949,
#              'confidence': 100.0,
#              'surface_temperature': 98.0}}
#
# {'hotspot': {'longitude': 143.6243,
#              'latitude': -37.8247,
#              'confidence': 95.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 143.6932,
#              'latitude': -37.4028,
#              'confidence': 95.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 143.6884,
#              'latitude': -37.4033,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 143.6174,
#              'latitude': -37.8249,
#              'confidence': 100.0,
#              'surface_temperature': 98.0}}
#
# {'hotspot': {'longitude': 142.5024,
#              'latitude': -36.6823,
#              'confidence': 93.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 144.7685,
#              'latitude': -36.4489,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 142.2012,
#              'latitude': -36.9498,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 143.1604,
#              'latitude': -36.1941,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 143.1077,
#              'latitude': -36.4142,
#              'confidence': 100.0,
#              'surface_temperature': 97.0}}
#
# {'hotspot': {'longitude': 143.1716,
#              'latitude': -36.1924,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 143.6409,
#              'latitude': -36.0295,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.0574,
#              'latitude': -37.0761,
#              'confidence': 100.0,
#              'surface_temperature': 89.0}}
#
# {'hotspot': {'longitude': 141.4417,
#              'latitude': -35.0616,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 144.737,
#              'latitude': -36.3999,
#              'confidence': 100.0,
#              'surface_temperature': 88.0}}
#
# {'hotspot': {'longitude': 145.7582,
#              'latitude': -36.1748,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 145.7797,
#              'latitude': -36.0691,
#              'confidence': 99.0,
#              'surface_temperature': 85.0}}
#
# {'hotspot': {'longitude': 141.0622,
#              'latitude': -35.1949,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 141.2705,
#              'latitude': -36.91,
#              'confidence': 100.0,
#              'surface_temperature': 96.0}}
#
# {'hotspot': {'longitude': 142.7318,
#              'latitude': -35.8071,
#              'confidence': 89.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 141.4449,
#              'latitude': -36.7787,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 141.3486,
#              'latitude': -36.2948,
#              'confidence': 98.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 143.7846,
#              'latitude': -38.1561,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 142.5609,
#              'latitude': -37.8185,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 145.7451,
#              'latitude': -36.1771,
#              'confidence': 100.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 142.3844,
#              'latitude': -38.027,
#              'confidence': 100.0,
#              'surface_temperature': 95.0}}
#
# {'hotspot': {'longitude': 143.3321,
#              'latitude': -35.7642,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.5759,
#              'latitude': -36.429,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 145.2196,
#              'latitude': -36.1346,
#              'confidence': 92.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 141.0238,
#              'latitude': -37.0899,
#              'confidence': 100.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 141.3146,
#              'latitude': -36.3823,
#              'confidence': 95.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 145.2096,
#              'latitude': -36.1462,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 142.0839,
#              'latitude': -36.5243,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 143.0013,
#              'latitude': -37.618,
#              'confidence': 98.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 142.1873,
#              'latitude': -36.8867,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 143.4996,
#              'latitude': -36.9364,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 142.8935,
#              'latitude': -37.3847,
#              'confidence': 100.0,
#              'surface_temperature': 88.0}}
#
# {'hotspot': {'longitude': 142.3787,
#              'latitude': -35.6374,
#              'confidence': 100.0,
#              'surface_temperature': 95.0}}
#
# {'hotspot': {'longitude': 142.2098,
#              'latitude': -36.8835,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 143.1189,
#              'latitude': -36.4125,
#              'confidence': 100.0,
#              'surface_temperature': 92.0}}
#
# {'hotspot': {'longitude': 141.0556,
#              'latitude': -37.0669,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 145.7665,
#              'latitude': -36.0714,
#              'confidence': 92.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 141.36,
#              'latitude': -36.2933,
#              'confidence': 94.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 144.9492,
#              'latitude': -37.4591,
#              'confidence': 100.0,
#              'surface_temperature': 89.0}}
#
# {'hotspot': {'longitude': 145.5315,
#              'latitude': -36.3487,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 144.678,
#              'latitude': -36.5399,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 142.6229,
#              'latitude': -36.8158,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 144.7752,
#              'latitude': -36.4518,
#              'confidence': 100.0,
#              'surface_temperature': 97.0}}
#
# {'hotspot': {'longitude': 141.618,
#              'latitude': -36.7903,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 143.7948,
#              'latitude': -36.1067,
#              'confidence': 97.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 145.2221,
#              'latitude': -36.1441,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.6635,
#              'latitude': -36.4816,
#              'confidence': 94.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 144.2448,
#              'latitude': -36.0837,
#              'confidence': 100.0,
#              'surface_temperature': 87.0}}
#
# {'hotspot': {'longitude': 141.8851,
#              'latitude': -36.782,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 144.0423,
#              'latitude': -36.5586,
#              'confidence': 92.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 144.0538,
#              'latitude': -36.5568,
#              'confidence': 90.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 144.763,
#              'latitude': -36.4538,
#              'confidence': 97.0,
#              'surface_temperature': 81.0}}
#
# {'hotspot': {'longitude': 144.7775,
#              'latitude': -36.4612,
#              'confidence': 91.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 143.3518,
#              'latitude': -36.7089,
#              'confidence': 100.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 144.6378,
#              'latitude': -36.601,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 143.5186,
#              'latitude': -36.8681,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 143.8231,
#              'latitude': -37.1999,
#              'confidence': 100.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 142.9426,
#              'latitude': -37.6171,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 142.8521,
#              'latitude': -37.7587,
#              'confidence': 84.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 144.9371,
#              'latitude': -37.4611,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 142.3959,
#              'latitude': -38.0254,
#              'confidence': 100.0,
#              'surface_temperature': 99.0}}
#
# {'hotspot': {'longitude': 143.7233,
#              'latitude': -37.88,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 143.9157,
#              'latitude': -37.8885,
#              'confidence': 99.0,
#              'surface_temperature': 85.0}}
#
# {'hotspot': {'longitude': 141.4435,
#              'latitude': -35.0706,
#              'confidence': 95.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 143.2449,
#              'latitude': -38.0795,
#              'confidence': 100.0,
#              'surface_temperature': 91.0}}
#
# {'hotspot': {'longitude': 141.0604,
#              'latitude': -35.1857,
#              'confidence': 100.0,
#              'surface_temperature': 92.0}}
#
# {'hotspot': {'longitude': 142.376,
#              'latitude': -35.6469,
#              'confidence': 100.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 142.387,
#              'latitude': -35.6453,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 141.6948,
#              'latitude': -36.4409,
#              'confidence': 100.0,
#              'surface_temperature': 92.0}}
#
# {'hotspot': {'longitude': 145.8678,
#              'latitude': -37.9174,
#              'confidence': 100.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 145.8808,
#              'latitude': -37.9152,
#              'confidence': 95.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 146.2035,
#              'latitude': -37.8906,
#              'confidence': 95.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 143.8739,
#              'latitude': -35.8182,
#              'confidence': 100.0,
#              'surface_temperature': 92.0}}
#
# {'hotspot': {'longitude': 146.2464,
#              'latitude': -37.9246,
#              'confidence': 100.0,
#              'surface_temperature': 96.0}}
#
# {'hotspot': {'longitude': 141.0017,
#              'latitude': -36.3313,
#              'confidence': 94.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 141.3467,
#              'latitude': -36.2857,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 143.4058,
#              'latitude': -36.0749,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 140.9836,
#              'latitude': -36.4449,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 141.6041,
#              'latitude': -36.3972,
#              'confidence': 100.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 142.5349,
#              'latitude': -36.5532,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 145.2071,
#              'latitude': -36.1367,
#              'confidence': 92.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 144.0233,
#              'latitude': -36.1518,
#              'confidence': 96.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 144.0261,
#              'latitude': -36.1418,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 141.3006,
#              'latitude': -36.7499,
#              'confidence': 75.0,
#              'surface_temperature': 99.0}}
#
# {'hotspot': {'longitude': 141.3296,
#              'latitude': -36.7432,
#              'confidence': 84.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 141.3253,
#              'latitude': -36.7531,
#              'confidence': 84.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 143.9571,
#              'latitude': -36.7943,
#              'confidence': 99.0,
#              'surface_temperature': 84.0}}
#
# {'hotspot': {'longitude': 143.9652,
#              'latitude': -36.7957,
#              'confidence': 100.0,
#              'surface_temperature': 87.0}}
#
# {'hotspot': {'longitude': 143.7796,
#              'latitude': -36.9329,
#              'confidence': 98.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 143.7549,
#              'latitude': -35.8276,
#              'confidence': 99.0,
#              'surface_temperature': 85.0}}
#
# {'hotspot': {'longitude': 141.958,
#              'latitude': -35.9326,
#              'confidence': 78.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 145.2775,
#              'latitude': -36.6892,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 143.935,
#              'latitude': -36.73,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 143.4605,
#              'latitude': -36.8283,
#              'confidence': 100.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 142.7392,
#              'latitude': -36.6527,
#              'confidence': 97.0,
#              'surface_temperature': 81.0}}
#
# {'hotspot': {'longitude': 145.0922,
#              'latitude': -36.1898,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 143.4483,
#              'latitude': -36.8298,
#              'confidence': 96.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 144.6014,
#              'latitude': -36.6615,
#              'confidence': 100.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 143.5724,
#              'latitude': -36.8238,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 145.0941,
#              'latitude': -36.1988,
#              'confidence': 100.0,
#              'surface_temperature': 100.0}}
#
# {'hotspot': {'longitude': 143.5801,
#              'latitude': -36.7651,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 144.7311,
#              'latitude': -36.5199,
#              'confidence': 95.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 145.3625,
#              'latitude': -37.0782,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 141.406,
#              'latitude': -36.3966,
#              'confidence': 94.0,
#              'surface_temperature': 74.0}}
#
# {'hotspot': {'longitude': 141.9491,
#              'latitude': -37.1349,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 142.5968,
#              'latitude': -37.6397,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 142.9993,
#              'latitude': -37.6267,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 144.4958,
#              'latitude': -36.5871,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 141.8783,
#              'latitude': -36.2618,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 144.784,
#              'latitude': -36.6828,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 143.0592,
#              'latitude': -37.4843,
#              'confidence': 89.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 142.9536,
#              'latitude': -37.7274,
#              'confidence': 94.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 142.8583,
#              'latitude': -37.6964,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 143.9423,
#              'latitude': -38.0509,
#              'confidence': 98.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 143.108,
#              'latitude': -37.9284,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 142.6497,
#              'latitude': -37.5701,
#              'confidence': 100.0,
#              'surface_temperature': 94.0}}
#
# {'hotspot': {'longitude': 142.3865,
#              'latitude': -36.7101,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 143.0466,
#              'latitude': -38.1693,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 142.3717,
#              'latitude': -36.7128,
#              'confidence': 95.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 142.0658,
#              'latitude': -37.4885,
#              'confidence': 97.0,
#              'surface_temperature': 81.0}}
#
# {'hotspot': {'longitude': 142.981,
#              'latitude': -36.7101,
#              'confidence': 77.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 143.8206,
#              'latitude': -37.0959,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 143.5638,
#              'latitude': -37.9594,
#              'confidence': 100.0,
#              'surface_temperature': 87.0}}
#
# {'hotspot': {'longitude': 144.4905,
#              'latitude': -36.5921,
#              'confidence': 98.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 144.8042,
#              'latitude': -36.6787,
#              'confidence': 96.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 146.4048,
#              'latitude': -38.0423,
#              'confidence': 84.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 143.7553,
#              'latitude': -38.1224,
#              'confidence': 94.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 143.7361,
#              'latitude': -38.0792,
#              'confidence': 94.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 143.3544,
#              'latitude': -37.9157,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 143.1606,
#              'latitude': -37.7935,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 143.1388,
#              'latitude': -37.7756,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 142.9505,
#              'latitude': -37.7171,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 142.947,
#              'latitude': -37.7236,
#              'confidence': 94.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 142.9562,
#              'latitude': -37.7002,
#              'confidence': 100.0,
#              'surface_temperature': 89.0}}
#
# {'hotspot': {'longitude': 142.5997,
#              'latitude': -37.6498,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 142.6348,
#              'latitude': -37.5728,
#              'confidence': 100.0,
#              'surface_temperature': 98.0}}
#
# {'hotspot': {'longitude': 143.1444,
#              'latitude': -37.4352,
#              'confidence': 100.0,
#              'surface_temperature': 96.0}}
#
# {'hotspot': {'longitude': 144.5775,
#              'latitude': -36.5828,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 144.4995,
#              'latitude': -36.5987,
#              'confidence': 96.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 144.5737,
#              'latitude': -36.5262,
#              'confidence': 98.0,
#              'surface_temperature': 84.0}}
#
# {'hotspot': {'longitude': 142.978,
#              'latitude': -36.6995,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 141.6647,
#              'latitude': -36.8879,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 145.4627,
#              'latitude': -35.8768,
#              'confidence': 100.0,
#              'surface_temperature': 86.0}}
#
# {'hotspot': {'longitude': 142.2805,
#              'latitude': -36.4899,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 141.3038,
#              'latitude': -36.663,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 141.7306,
#              'latitude': -36.092,
#              'confidence': 94.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 142.0557,
#              'latitude': -34.9023,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 145.3649,
#              'latitude': -36.2637,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 141.7999,
#              'latitude': -37.2609,
#              'confidence': 89.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 141.0704,
#              'latitude': -36.91,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 145.3769,
#              'latitude': -36.2652,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 142.1177,
#              'latitude': -36.738,
#              'confidence': 95.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 143.7804,
#              'latitude': -37.876,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.8146,
#              'latitude': -36.1546,
#              'confidence': 88.0,
#              'surface_temperature': 74.0}}
#
# {'hotspot': {'longitude': 143.5105,
#              'latitude': -37.9091,
#              'confidence': 87.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 141.8102,
#              'latitude': -36.1559,
#              'confidence': 80.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 143.538,
#              'latitude': -37.9071,
#              'confidence': 100.0,
#              'surface_temperature': 88.0}}
#
# {'hotspot': {'longitude': 148.2955,
#              'latitude': -37.3902,
#              'confidence': 100.0,
#              'surface_temperature': 98.0}}
#
# {'hotspot': {'longitude': 146.347,
#              'latitude': -37.5027,
#              'confidence': 100.0,
#              'surface_temperature': 95.0}}
#
# {'hotspot': {'longitude': 146.3299,
#              'latitude': -37.5043,
#              'confidence': 100.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 144.5217,
#              'latitude': -36.1964,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 147.94,
#              'latitude': -37.769,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 146.3606,
#              'latitude': -36.1303,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 146.351,
#              'latitude': -36.1345,
#              'confidence': 98.0,
#              'surface_temperature': 84.0}}
#
# {'hotspot': {'longitude': 145.6666,
#              'latitude': -36.1586,
#              'confidence': 99.0,
#              'surface_temperature': 85.0}}
#
# {'hotspot': {'longitude': 145.1968,
#              'latitude': -36.5847,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 142.692,
#              'latitude': -36.9111,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 143.14,
#              'latitude': -37.5115,
#              'confidence': 99.0,
#              'surface_temperature': 86.0}}
#
# {'hotspot': {'longitude': 148.5131,
#              'latitude': -37.6775,
#              'confidence': 86.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 145.8594,
#              'latitude': -36.3332,
#              'confidence': 87.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 143.1034,
#              'latitude': -36.9303,
#              'confidence': 70.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 146.0601,
#              'latitude': -36.3195,
#              'confidence': 83.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 143.0588,
#              'latitude': -36.5839,
#              'confidence': 100.0,
#              'surface_temperature': 99.0}}
#
# {'hotspot': {'longitude': 143.0462,
#              'latitude': -36.5854,
#              'confidence': 100.0,
#              'surface_temperature': 94.0}}
#
# {'hotspot': {'longitude': 143.203,
#              'latitude': -36.3014,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 147.0745,
#              'latitude': -38.1917,
#              'confidence': 100.0,
#              'surface_temperature': 94.0}}
#
# {'hotspot': {'longitude': 147.0666,
#              'latitude': -38.1987,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 144.7402,
#              'latitude': -36.5454,
#              'confidence': 100.0,
#              'surface_temperature': 96.0}}
#
# {'hotspot': {'longitude': 142.895,
#              'latitude': -36.7593,
#              'confidence': 92.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 141.5513,
#              'latitude': -36.3435,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 143.8021,
#              'latitude': -36.6942,
#              'confidence': 93.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 141.5586,
#              'latitude': -36.3459,
#              'confidence': 100.0,
#              'surface_temperature': 91.0}}
#
# {'hotspot': {'longitude': 141.1534,
#              'latitude': -36.4046,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 141.5907,
#              'latitude': -36.0594,
#              'confidence': 96.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 141.6122,
#              'latitude': -36.0576,
#              'confidence': 100.0,
#              'surface_temperature': 94.0}}
#
# {'hotspot': {'longitude': 141.8309,
#              'latitude': -36.388,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 145.7646,
#              'latitude': -36.094,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 144.7548,
#              'latitude': -36.5438,
#              'confidence': 99.0,
#              'surface_temperature': 84.0}}
#
# {'hotspot': {'longitude': 143.8781,
#              'latitude': -36.6537,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 142.8567,
#              'latitude': -36.663,
#              'confidence': 92.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 143.0549,
# ...
#              'confidence': 96.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 147.2232,
#              'latitude': -37.8323,
#              'confidence': 84.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 145.9519,
#              'latitude': -38.2853,
#              'confidence': 98.0,
#              'surface_temperature': 83.0}}
#
# {'hotspot': {'longitude': 142.8363,
#              'latitude': -38.2375,
#              'confidence': 98.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 142.7829,
#              'latitude': -37.4463,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 143.4543,
#              'latitude': -37.6854,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 143.9391,
#              'latitude': -38.0881,
#              'confidence': 99.0,
#              'surface_temperature': 84.0}}
#
# {'hotspot': {'longitude': 143.9534,
#              'latitude': -38.0866,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 142.82,
#              'latitude': -38.2391,
#              'confidence': 92.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 146.4007,
#              'latitude': -38.5123,
#              'confidence': 100.0,
#              'surface_temperature': 89.0}}
#
# {'hotspot': {'longitude': 141.5832,
#              'latitude': -36.3438,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 142.7813,
#              'latitude': -37.4357,
#              'confidence': 94.0,
#              'surface_temperature': 74.0}}
#
# {'hotspot': {'longitude': 143.6256,
#              'latitude': -37.5867,
#              'confidence': 99.0,
#              'surface_temperature': 85.0}}
#
# {'hotspot': {'longitude': 141.1664,
#              'latitude': -36.2911,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 141.1741,
#              'latitude': -36.2842,
#              'confidence': 96.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 141.6411,
#              'latitude': -36.7218,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.3903,
#              'latitude': -37.3656,
#              'confidence': 84.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 144.2924,
#              'latitude': -36.4179,
#              'confidence': 94.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 140.9737,
#              'latitude': -36.3207,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 141.1821,
#              'latitude': -36.2882,
#              'confidence': 99.0,
#              'surface_temperature': 86.0}}
#
# {'hotspot': {'longitude': 140.9789,
#              'latitude': -36.3153,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 144.2994,
#              'latitude': -36.4169,
#              'confidence': 97.0,
#              'surface_temperature': 81.0}}
#
# {'hotspot': {'longitude': 145.9962,
#              'latitude': -37.4671,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 144.3638,
#              'latitude': -36.3254,
#              'confidence': 95.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 145.859,
#              'latitude': -36.0816,
#              'confidence': 100.0,
#              'surface_temperature': 98.0}}
#
# {'hotspot': {'longitude': 143.5527,
#              'latitude': -36.1532,
#              'confidence': 100.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 141.7747,
#              'latitude': -36.0077,
#              'confidence': 100.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 145.873,
#              'latitude': -36.0828,
#              'confidence': 94.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 144.1321,
#              'latitude': -36.5541,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 143.5275,
#              'latitude': -35.6819,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 143.5235,
#              'latitude': -35.6871,
#              'confidence': 90.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 143.5671,
#              'latitude': -36.1506,
#              'confidence': 100.0,
#              'surface_temperature': 95.0}}
#
# {'hotspot': {'longitude': 142.9739,
#              'latitude': -37.4984,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 144.3681,
#              'latitude': -37.253,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 143.1462,
#              'latitude': -36.9396,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 141.7542,
#              'latitude': -36.3387,
#              'confidence': 96.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 143.4369,
#              'latitude': -36.3433,
#              'confidence': 100.0,
#              'surface_temperature': 94.0}}
#
# {'hotspot': {'longitude': 143.4256,
#              'latitude': -36.345,
#              'confidence': 100.0,
#              'surface_temperature': 87.0}}
#
# {'hotspot': {'longitude': 144.0992,
#              'latitude': -36.7032,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 141.7429,
#              'latitude': -36.3402,
#              'confidence': 96.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 142.2956,
#              'latitude': -36.5661,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 143.6038,
#              'latitude': -36.5023,
#              'confidence': 85.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 142.8025,
#              'latitude': -36.8616,
#              'confidence': 90.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 146.0616,
#              'latitude': -38.0372,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 146.0513,
#              'latitude': -38.049,
#              'confidence': 94.0,
#              'surface_temperature': 74.0}}
#
# {'hotspot': {'longitude': 142.0749,
#              'latitude': -35.4666,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.7183,
#              'latitude': -36.0396,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 146.1026,
#              'latitude': -36.2775,
#              'confidence': 94.0,
#              'surface_temperature': 74.0}}
#
# {'hotspot': {'longitude': 146.0567,
#              'latitude': -38.0361,
#              'confidence': 100.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 146.6642,
#              'latitude': -36.7746,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 146.6448,
#              'latitude': -36.8359,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 141.1038,
#              'latitude': -37.9085,
#              'confidence': 98.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 146.3122,
#              'latitude': -38.4349,
#              'confidence': 100.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 146.3081,
#              'latitude': -38.4792,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.0945,
#              'latitude': -37.9047,
#              'confidence': 100.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 142.7134,
#              'latitude': -36.7685,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 142.7151,
#              'latitude': -36.7801,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 142.3405,
#              'latitude': -36.1002,
#              'confidence': 96.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 144.3142,
#              'latitude': -36.4325,
#              'confidence': 90.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 143.1768,
#              'latitude': -36.2693,
#              'confidence': 94.0,
#              'surface_temperature': 85.0}}
#
# {'hotspot': {'longitude': 143.7079,
#              'latitude': -36.3774,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 143.7243,
#              'latitude': -36.3756,
#              'confidence': 100.0,
#              'surface_temperature': 88.0}}
#
# {'hotspot': {'longitude': 143.7132,
#              'latitude': -36.369,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 143.7149,
#              'latitude': -36.3799,
#              'confidence': 100.0,
#              'surface_temperature': 89.0}}
#
# {'hotspot': {'longitude': 143.4263,
#              'latitude': -37.8644,
#              'confidence': 91.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 147.064,
#              'latitude': -38.3998,
#              'confidence': 89.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 141.9403,
#              'latitude': -37.4796,
#              'confidence': 94.0,
#              'surface_temperature': 87.0}}
#
# {'hotspot': {'longitude': 148.126,
#              'latitude': -37.379,
#              'confidence': 58.0,
#              'surface_temperature': 82.0}}
#
# {'hotspot': {'longitude': 148.132,
#              'latitude': -37.379,
#              'confidence': 62.0,
#              'surface_temperature': 78.0}}
#
# {'hotspot': {'longitude': 148.086,
#              'latitude': -37.396,
#              'confidence': 100.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 148.081,
#              'latitude': -37.399,
#              'confidence': 100.0,
#              'surface_temperature': 84.0}}
#
# {'hotspot': {'longitude': 148.067,
#              'latitude': -37.401,
#              'confidence': 100.0,
#              'surface_temperature': 79.0}}
#
# {'hotspot': {'longitude': 148.102,
#              'latitude': -37.446,
#              'confidence': 100.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 148.123,
#              'latitude': -37.406,
#              'confidence': 100.0,
#              'surface_temperature': 88.0}}
#
# {'hotspot': {'longitude': 148.115,
#              'latitude': -37.452,
#              'confidence': 68.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 148.126,
#              'latitude': -37.45,
#              'confidence': 64.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 148.088,
#              'latitude': -37.436,
#              'confidence': 86.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 148.101,
#              'latitude': -37.444,
#              'confidence': 73.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 148.05,
#              'latitude': -37.562,
#              'confidence': 61.0,
#              'surface_temperature': 72.0}}
#
# {'hotspot': {'longitude': 148.089,
#              'latitude': -37.462,
#              'confidence': 100.0,
#              'surface_temperature': 90.0}}
#
# {'hotspot': {'longitude': 148.102,
#              'latitude': -37.46,
#              'confidence': 88.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 143.82,
#              'latitude': -38.127,
#              'confidence': 96.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 141.232,
#              'latitude': -37.294,
#              'confidence': 100.0,
#              'surface_temperature': 87.0}}
#
# {'hotspot': {'longitude': 141.245,
#              'latitude': -37.293,
#              'confidence': 99.0,
#              'surface_temperature': 85.0}}
#
# {'hotspot': {'longitude': 141.278,
#              'latitude': -37.247,
#              'confidence': 91.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 143.74,
#              'latitude': -36.098,
#              'confidence': 92.0,
#              'surface_temperature': 67.0}}
#
# {'hotspot': {'longitude': 143.122,
#              'latitude': -37.331,
#              'confidence': 90.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 143.352,
#              'latitude': -37.477,
#              'confidence': 100.0,
#              'surface_temperature': 93.0}}
#
# {'hotspot': {'longitude': 143.365,
#              'latitude': -37.475,
#              'confidence': 96.0,
#              'surface_temperature': 77.0}}
#
# {'hotspot': {'longitude': 143.605,
#              'latitude': -37.69,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 143.281,
#              'latitude': -36.94,
#              'confidence': 89.0,
#              'surface_temperature': 69.0}}
#
# {'hotspot': {'longitude': 144.175,
#              'latitude': -37.862,
#              'confidence': 87.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 144.354,
#              'latitude': -37.945,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 149.312,
#              'latitude': -37.606,
#              'confidence': 100.0,
#              'surface_temperature': 87.0}}
#
# {'hotspot': {'longitude': 149.307,
#              'latitude': -37.61,
#              'confidence': 97.0,
#              'surface_temperature': 80.0}}
#
# {'hotspot': {'longitude': 149.32,
#              'latitude': -37.609,
#              'confidence': 99.0,
#              'surface_temperature': 84.0}}
#
# {'hotspot': {'longitude': 149.263,
#              'latitude': -37.642,
#              'confidence': 100.0,
#              'surface_temperature': 65.0}}
#
# {'hotspot': {'longitude': 149.237,
#              'latitude': -37.634,
#              'confidence': 100.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 149.302,
#              'latitude': -37.605,
#              'confidence': 98.0,
#              'surface_temperature': 83.0}}
#
# {'hotspot': {'longitude': 149.325,
#              'latitude': -37.6,
#              'confidence': 99.0,
#              'surface_temperature': 86.0}}
#
# {'hotspot': {'longitude': 149.281,
#              'latitude': -37.618,
#              'confidence': 95.0,
#              'surface_temperature': 76.0}}
#
# {'hotspot': {'longitude': 146.157,
#              'latitude': -36.282,
#              'confidence': 100.0,
#              'surface_temperature': 71.0}}
#
# {'hotspot': {'longitude': 142.366,
#              'latitude': -37.95,
#              'confidence': 92.0,
#              'surface_temperature': 70.0}}
#
# {'hotspot': {'longitude': 142.51,
#              'latitude': -37.875,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 149.305,
#              'latitude': -37.613,
#              'confidence': 95.0,
#              'surface_temperature': 75.0}}
#
# {'hotspot': {'longitude': 149.314,
#              'latitude': -37.624,
#              'confidence': 90.0,
#              'surface_temperature': 66.0}}
#
# {'hotspot': {'longitude': 144.211,
#              'latitude': -38.057,
#              'confidence': 93.0,
#              'surface_temperature': 73.0}}
#
# {'hotspot': {'longitude': 145.051,
#              'latitude': -37.966,
#              'confidence': 78.0,
#              'surface_temperature': 68.0}}
#
# {'hotspot': {'longitude': 143.316,
#              'latitude': -35.543,
#              'confidence': 86.0,
#              'surface_temperature': 67.0}}

# %% [markdown]
# c) Find date, surface temperature (°C), air temperature (°C), relative humidity and max wind speed on 15th and 16th of December 2022.

# %%
response = fire_collection.find(
    {'date':{
        '$in':[date_to_iso('15/12/2022'), date_to_iso('16/12/2022')]
    }},
    {'_id':0, 
     'date':1, 
     'hotspot.datetime':1,
     'hotspot.surface_temperature':1,
     'air_temperature':1,
     'relative_humidity':1, 
     'max_wind_speed':1}
)

# %%
print_response(response)
# Out:
# {'date': datetime.datetime(2022, 12, 15, 0, 0),
#  'hotspot': [{'datetime': datetime.datetime(2022, 12, 15, 13, 17, 17),
#               'surface_temperature': 42.0},
#              {'datetime': datetime.datetime(2022, 12, 15, 13, 17, 17),
#               'surface_temperature': 36.0},
#              {'datetime': datetime.datetime(2022, 12, 15, 13, 17, 17),
#               'surface_temperature': 38.0},
#              {'datetime': datetime.datetime(2022, 12, 15, 1, 16, 23),
#               'surface_temperature': 40.0}],
#  'air_temperature': 18.0,
#  'relative_humidity': 52.0,
#  'max_wind_speed': 14.0}
#
# {'date': datetime.datetime(2022, 12, 16, 0, 0),
#  'hotspot': [{'datetime': datetime.datetime(2022, 12, 16, 15, 38, 39),
#               'surface_temperature': 43.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 15, 38, 39),
#               'surface_temperature': 33.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 4, 35, 15),
#               'surface_temperature': 54.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 4, 35, 13),
#               'surface_temperature': 73.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 4, 34, 58),
#               'surface_temperature': 55.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 4, 34, 58),
#               'surface_temperature': 75.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#               'surface_temperature': 55.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#               'surface_temperature': 66.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#               'surface_temperature': 56.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#               'surface_temperature': 60.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 0, 21, 12),
#               'surface_temperature': 73.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 0, 21, 11),
#               'surface_temperature': 48.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 0, 21, 11),
#               'surface_temperature': 55.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 0, 20, 53),
#               'surface_temperature': 64.0},
#              {'datetime': datetime.datetime(2022, 12, 16, 0, 20, 53),
#               'surface_temperature': 57.0}],
#  'air_temperature': 18.0,
#  'relative_humidity': 53.7,
#  'max_wind_speed': 13.0}

# %% [markdown]
# d) Find datetime, air temperature (°C), surface temperature (°C) and confidence when the confidence is between 80 and 100.

# %%
response = fire_collection.aggregate([
    {'$unwind':'$hotspot'},
    {'$match':{'hotspot.confidence':{'$gte':80, '$lte':100}}},
    {'$project':{
        '_id':0,
        'hotspot.datetime':1,
        'air_temperature':1,
        'hotspot.surface_temperature':1,
        'hotspot.confidence':1
    }}
])

# %%
print_response(response)
# Out:
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 6, 5, 6, 30),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 20.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 6, 5, 6, 20),
#              'confidence': 85.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 20.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 7, 4, 16, 10),
#              'confidence': 88.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 9, 13, 23, 40),
#              'confidence': 86.0,
#              'surface_temperature': 41.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 10, 4, 48, 40),
#              'confidence': 100.0,
#              'surface_temperature': 105.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 10, 4, 46, 20),
#              'confidence': 100.0,
#              'surface_temperature': 109.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 10, 4, 45, 30),
#              'confidence': 94.0,
#              'surface_temperature': 73.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 10, 4, 45, 30),
#              'confidence': 97.0,
#              'surface_temperature': 80.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 10, 4, 43, 50),
#              'confidence': 81.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 12, 4, 33, 50),
#              'confidence': 94.0,
#              'surface_temperature': 105.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 12, 4, 29, 50),
#              'confidence': 84.0,
#              'surface_temperature': 71.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 12, 4, 28, 20),
#              'confidence': 100.0,
#              'surface_temperature': 99.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 12, 4, 28),
#              'confidence': 80.0,
#              'surface_temperature': 68.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 12, 4, 27, 20),
#              'confidence': 85.0,
#              'surface_temperature': 98.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 14, 4, 24, 40),
#              'confidence': 90.0,
#              'surface_temperature': 67.0},
#  'air_temperature': 25.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 14, 4, 22, 20),
#              'confidence': 93.0,
#              'surface_temperature': 72.0},
#  'air_temperature': 25.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 14, 4, 20, 50),
#              'confidence': 90.0,
#              'surface_temperature': 68.0},
#  'air_temperature': 25.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 14, 4, 16, 30),
#              'confidence': 95.0,
#              'surface_temperature': 75.0},
#  'air_temperature': 25.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 14, 4, 16, 20),
#              'confidence': 89.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 25.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 14, 4, 14, 40),
#              'confidence': 81.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 25.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 14, 4, 14, 30),
#              'confidence': 96.0,
#              'surface_temperature': 79.0},
#  'air_temperature': 25.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 14, 4, 14, 30),
#              'confidence': 94.0,
#              'surface_temperature': 75.0},
#  'air_temperature': 25.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 17, 4, 48, 20),
#              'confidence': 94.0,
#              'surface_temperature': 74.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 17, 4, 45, 10),
#              'confidence': 84.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 17, 4, 45),
#              'confidence': 86.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 18, 3, 50, 50),
#              'confidence': 100.0,
#              'surface_temperature': 121.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 18, 3, 50, 40),
#              'confidence': 97.0,
#              'surface_temperature': 80.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 19, 4, 39, 50),
#              'confidence': 85.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 19, 4, 39, 20),
#              'confidence': 96.0,
#              'surface_temperature': 79.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 19, 4, 36),
#              'confidence': 90.0,
#              'surface_temperature': 66.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 19, 4, 33),
#              'confidence': 98.0,
#              'surface_temperature': 83.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 19, 4, 32, 50),
#              'confidence': 100.0,
#              'surface_temperature': 91.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 19, 4, 32, 50),
#              'confidence': 84.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 19, 4, 32, 40),
#              'confidence': 100.0,
#              'surface_temperature': 113.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 19, 4, 32, 40),
#              'confidence': 92.0,
#              'surface_temperature': 70.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 19, 4, 32, 40),
#              'confidence': 100.0,
#              'surface_temperature': 106.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 25, 3, 59, 50),
#              'confidence': 82.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 25, 3, 58, 10),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 25, 3, 58, 10),
#              'confidence': 95.0,
#              'surface_temperature': 75.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 25, 3, 57, 10),
#              'confidence': 85.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 25, 3, 57, 10),
#              'confidence': 100.0,
#              'surface_temperature': 111.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 25, 3, 57, 10),
#              'confidence': 95.0,
#              'surface_temperature': 77.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 25, 3, 56, 40),
#              'confidence': 100.0,
#              'surface_temperature': 99.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 26, 4, 43, 20),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 26, 4, 40, 50),
#              'confidence': 80.0,
#              'surface_temperature': 53.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 26, 4, 39, 50),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#              'confidence': 91.0,
#              'surface_temperature': 68.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#              'confidence': 92.0,
#              'surface_temperature': 70.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#              'confidence': 100.0,
#              'surface_temperature': 89.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#              'confidence': 82.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#              'confidence': 84.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 38),
#              'confidence': 88.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 33, 40),
#              'confidence': 86.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 33, 30),
#              'confidence': 92.0,
#              'surface_temperature': 71.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 33, 30),
#              'confidence': 95.0,
#              'surface_temperature': 76.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 32, 20),
#              'confidence': 93.0,
#              'surface_temperature': 73.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 30, 50),
#              'confidence': 83.0,
#              'surface_temperature': 56.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 30, 20),
#              'confidence': 80.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 30, 10),
#              'confidence': 94.0,
#              'surface_temperature': 74.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 30, 10),
#              'confidence': 98.0,
#              'surface_temperature': 82.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 30, 10),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 30, 10),
#              'confidence': 97.0,
#              'surface_temperature': 80.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 28, 30),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 28, 30),
#              'confidence': 88.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 28, 30),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 27, 40),
#              'confidence': 97.0,
#              'surface_temperature': 80.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 27, 20),
#              'confidence': 100.0,
#              'surface_temperature': 107.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 27, 10),
#              'confidence': 100.0,
#              'surface_temperature': 108.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 27),
#              'confidence': 82.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 27),
#              'confidence': 99.0,
#              'surface_temperature': 86.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 81.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 80.0,
#              'surface_temperature': 53.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 83.0,
#              'surface_temperature': 57.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 100.0,
#              'surface_temperature': 90.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 97.0,
#              'surface_temperature': 81.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 85.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 88.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 84.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 97.0,
#              'surface_temperature': 81.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 83.0,
#              'surface_temperature': 57.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 85.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 31, 5, 7, 10),
#              'confidence': 82.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 31, 5, 1, 20),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 31, 4, 58, 30),
#              'confidence': 82.0,
#              'surface_temperature': 56.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 31, 4, 58),
#              'confidence': 80.0,
#              'surface_temperature': 53.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 31, 4, 57, 10),
#              'confidence': 86.0,
#              'surface_temperature': 61.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 3, 31, 0, 36, 30),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 13, 17),
#              'confidence': 91.0,
#              'surface_temperature': 43.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 13, 15, 30),
#              'confidence': 83.0,
#              'surface_temperature': 40.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 13, 15, 10),
#              'confidence': 100.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 13, 15, 10),
#              'confidence': 96.0,
#              'surface_temperature': 45.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 59, 10),
#              'confidence': 87.0,
#              'surface_temperature': 96.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 57, 50),
#              'confidence': 93.0,
#              'surface_temperature': 72.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 56, 20),
#              'confidence': 82.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 55, 10),
#              'confidence': 88.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 55, 10),
#              'confidence': 95.0,
#              'surface_temperature': 77.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 54),
#              'confidence': 96.0,
#              'surface_temperature': 78.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 53, 50),
#              'confidence': 100.0,
#              'surface_temperature': 93.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 53, 30),
#              'confidence': 85.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 52, 30),
#              'confidence': 84.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 52, 30),
#              'confidence': 100.0,
#              'surface_temperature': 90.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 52, 20),
#              'confidence': 100.0,
#              'surface_temperature': 115.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 52, 10),
#              'confidence': 86.0,
#              'surface_temperature': 61.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 52, 10),
#              'confidence': 100.0,
#              'surface_temperature': 98.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 52, 10),
#              'confidence': 100.0,
#              'surface_temperature': 89.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 52, 10),
#              'confidence': 85.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 51, 30),
#              'confidence': 83.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 51, 30),
#              'confidence': 89.0,
#              'surface_temperature': 66.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 51, 10),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 51),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 51),
#              'confidence': 98.0,
#              'surface_temperature': 82.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 51),
#              'confidence': 80.0,
#              'surface_temperature': 53.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 51),
#              'confidence': 100.0,
#              'surface_temperature': 103.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#              'confidence': 87.0,
#              'surface_temperature': 97.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#              'confidence': 90.0,
#              'surface_temperature': 66.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 85.0,
#              'surface_temperature': 61.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 99.0,
#              'surface_temperature': 86.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 93.0,
#              'surface_temperature': 72.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 95.0,
#              'surface_temperature': 76.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 86.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 89.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 82.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 89.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 3, 1, 7, 20),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 15, 31),
#              'confidence': 93.0,
#              'surface_temperature': 44.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 15, 30, 40),
#              'confidence': 100.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 41, 50),
#              'confidence': 88.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 41, 10),
#              'confidence': 82.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 41),
#              'confidence': 88.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 41),
#              'confidence': 86.0,
#              'surface_temperature': 61.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 40),
#              'confidence': 100.0,
#              'surface_temperature': 120.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 39, 50),
#              'confidence': 90.0,
#              'surface_temperature': 67.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 39, 50),
#              'confidence': 85.0,
#              'surface_temperature': 66.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 39, 40),
#              'confidence': 90.0,
#              'surface_temperature': 66.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 39, 40),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 39, 20),
#              'confidence': 100.0,
#              'surface_temperature': 107.0},
#  'air_temperature': 16.0}
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 37, 10),
#              'confidence': 88.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 36, 10),
#              'confidence': 88.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 36, 10),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 36),
#              'confidence': 90.0,
#              'surface_temperature': 76.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 35),
#              'confidence': 100.0,
#              'surface_temperature': 95.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 34, 50),
#              'confidence': 83.0,
#              'surface_temperature': 57.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 34, 20),
#              'confidence': 89.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 34, 20),
#              'confidence': 96.0,
#              'surface_temperature': 78.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 34, 20),
#              'confidence': 85.0,
#              'surface_temperature': 66.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 34),
#              'confidence': 84.0,
#              'surface_temperature': 57.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 33, 50),
#              'confidence': 92.0,
#              'surface_temperature': 81.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 33, 40),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 33, 30),
#              'confidence': 100.0,
#              'surface_temperature': 113.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 33, 30),
#              'confidence': 80.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 33, 30),
#              'confidence': 85.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 33, 10),
#              'confidence': 82.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 33, 10),
#              'confidence': 82.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 33),
#              'confidence': 97.0,
#              'surface_temperature': 79.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 33),
#              'confidence': 86.0,
#              'surface_temperature': 61.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#              'confidence': 98.0,
#              'surface_temperature': 82.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#              'confidence': 85.0,
#              'surface_temperature': 61.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#              'confidence': 84.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#              'confidence': 82.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#              'confidence': 100.0,
#              'surface_temperature': 123.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#              'confidence': 82.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#              'confidence': 100.0,
#              'surface_temperature': 118.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 80.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 96.0,
#              'surface_temperature': 78.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 93.0,
#              'surface_temperature': 72.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 100.0,
#              'surface_temperature': 120.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 87.0,
#              'surface_temperature': 92.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 100.0,
#              'surface_temperature': 101.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 100.0,
#              'surface_temperature': 98.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 4, 0, 12, 50),
#              'confidence': 80.0,
#              'surface_temperature': 53.0},
#  'air_temperature': 16.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 9),
#              'confidence': 100.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 9),
#              'confidence': 81.0,
#              'surface_temperature': 39.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 8, 40),
#              'confidence': 93.0,
#              'surface_temperature': 44.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 8, 40),
#              'confidence': 100.0,
#              'surface_temperature': 47.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 7),
#              'confidence': 82.0,
#              'surface_temperature': 40.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 4, 20),
#              'confidence': 100.0,
#              'surface_temperature': 49.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 3, 20),
#              'confidence': 100.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 3),
#              'confidence': 98.0,
#              'surface_temperature': 45.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 3),
#              'confidence': 100.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 3),
#              'confidence': 81.0,
#              'surface_temperature': 39.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 2, 40),
#              'confidence': 88.0,
#              'surface_temperature': 42.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 13, 2, 40),
#              'confidence': 80.0,
#              'surface_temperature': 39.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 5, 16, 50),
#              'confidence': 87.0,
#              'surface_temperature': 88.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 5, 15, 30),
#              'confidence': 93.0,
#              'surface_temperature': 83.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 40, 50),
#              'confidence': 93.0,
#              'surface_temperature': 72.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 40, 30),
#              'confidence': 95.0,
#              'surface_temperature': 76.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 40, 20),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 39, 30),
#              'confidence': 89.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 39, 30),
#              'confidence': 82.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 39, 20),
#              'confidence': 90.0,
#              'surface_temperature': 66.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 39, 20),
#              'confidence': 83.0,
#              'surface_temperature': 56.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#              'confidence': 89.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#              'confidence': 83.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#              'confidence': 95.0,
#              'surface_temperature': 76.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#              'confidence': 100.0,
#              'surface_temperature': 92.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#              'confidence': 88.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#              'confidence': 89.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 13, 45, 30),
#              'confidence': 97.0,
#              'surface_temperature': 45.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 32, 20),
#              'confidence': 84.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 31, 10),
#              'confidence': 92.0,
#              'surface_temperature': 69.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 27, 50),
#              'confidence': 100.0,
#              'surface_temperature': 95.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 27, 50),
#              'confidence': 100.0,
#              'surface_temperature': 88.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 27, 10),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 27),
#              'confidence': 100.0,
#              'surface_temperature': 97.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 27),
#              'confidence': 86.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 27),
#              'confidence': 90.0,
#              'surface_temperature': 76.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 27),
#              'confidence': 100.0,
#              'surface_temperature': 99.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 27),
#              'confidence': 83.0,
#              'surface_temperature': 57.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 24, 40),
#              'confidence': 83.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 24, 20),
#              'confidence': 89.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 24, 20),
#              'confidence': 89.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 24),
#              'confidence': 89.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#              'confidence': 92.0,
#              'surface_temperature': 70.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#              'confidence': 99.0,
#              'surface_temperature': 85.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 23, 30),
#              'confidence': 93.0,
#              'surface_temperature': 72.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 23, 10),
#              'confidence': 89.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 23),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 22, 40),
#              'confidence': 85.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#              'confidence': 83.0,
#              'surface_temperature': 56.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#              'confidence': 81.0,
#              'surface_temperature': 71.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#              'confidence': 85.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#              'confidence': 100.0,
#              'surface_temperature': 103.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#              'confidence': 91.0,
#              'surface_temperature': 69.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 22, 10),
#              'confidence': 86.0,
#              'surface_temperature': 68.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 22, 10),
#              'confidence': 85.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 22, 10),
#              'confidence': 90.0,
#              'surface_temperature': 67.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 21, 30),
#              'confidence': 90.0,
#              'surface_temperature': 66.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 21, 10),
#              'confidence': 94.0,
#              'surface_temperature': 96.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 21),
#              'confidence': 100.0,
#              'surface_temperature': 115.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 21),
#              'confidence': 84.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 50),
#              'confidence': 100.0,
#              'surface_temperature': 95.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 50),
#              'confidence': 88.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 50),
#              'confidence': 83.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 81.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 83.0,
#              'surface_temperature': 78.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 96.0,
#              'surface_temperature': 77.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 91.0,
#              'surface_temperature': 68.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 97.0,
#              'surface_temperature': 81.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 82.0,
#              'surface_temperature': 56.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 94.0,
#              'surface_temperature': 104.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 92.0,
#              'surface_temperature': 71.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 81.0,
#              'surface_temperature': 61.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 80.0,
#              'surface_temperature': 53.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 85.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 90.0,
#              'surface_temperature': 67.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 94.0,
#              'surface_temperature': 86.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 84.0,
#              'surface_temperature': 57.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 100.0,
#              'surface_temperature': 100.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 86.0,
#              'surface_temperature': 72.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 81.0,
#              'surface_temperature': 57.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 94.0,
#              'surface_temperature': 89.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 12, 56, 50),
#              'confidence': 85.0,
#              'surface_temperature': 41.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 12, 56, 30),
#              'confidence': 80.0,
#              'surface_temperature': 39.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 12, 56, 30),
#              'confidence': 94.0,
#              'surface_temperature': 49.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 12, 53, 40),
#              'confidence': 86.0,
#              'surface_temperature': 41.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 12, 52, 10),
#              'confidence': 86.0,
#              'surface_temperature': 41.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 12, 51, 20),
#              'confidence': 97.0,
#              'surface_temperature': 45.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 12, 51),
#              'confidence': 100.0,
#              'surface_temperature': 49.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 12, 50, 50),
#              'confidence': 92.0,
#              'surface_temperature': 43.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 12, 50, 40),
#              'confidence': 89.0,
#              'surface_temperature': 42.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 5, 9, 50),
#              'confidence': 80.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 5, 3, 10),
#              'confidence': 80.0,
#              'surface_temperature': 53.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 5, 3, 10),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 3, 31, 40),
#              'confidence': 100.0,
#              'surface_temperature': 89.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 3, 28, 20),
#              'confidence': 96.0,
#              'surface_temperature': 78.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 3, 27, 30),
#              'confidence': 92.0,
#              'surface_temperature': 70.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 3, 27, 20),
#              'confidence': 92.0,
#              'surface_temperature': 70.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 3, 27, 20),
#              'confidence': 95.0,
#              'surface_temperature': 76.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 7, 3, 27, 10),
#              'confidence': 100.0,
#              'surface_temperature': 106.0},
#  'air_temperature': 21.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 8, 4, 14),
#              'confidence': 99.0,
#              'surface_temperature': 85.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 8, 4, 12, 50),
#              'confidence': 91.0,
#              'surface_temperature': 69.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 8, 4, 12, 20),
#              'confidence': 100.0,
#              'surface_temperature': 94.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 8, 4, 12),
#              'confidence': 80.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 8, 4, 8, 50),
#              'confidence': 98.0,
#              'surface_temperature': 83.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 4, 8, 4, 8, 30),
#              'confidence': 90.0,
#              'surface_temperature': 66.0},
#  'air_temperature': 19.0}
#
# ...
#  'air_temperature': 11.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 3, 13, 23, 43),
#              'confidence': 92.0,
#              'surface_temperature': 42.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 3, 3, 58, 15),
#              'confidence': 90.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 3, 3, 58, 15),
#              'confidence': 81.0,
#              'surface_temperature': 48.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 3, 3, 58, 15),
#              'confidence': 82.0,
#              'surface_temperature': 49.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 3, 3, 58, 15),
#              'confidence': 84.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 3, 3, 58, 15),
#              'confidence': 90.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 3, 3, 58, 14),
#              'confidence': 100.0,
#              'surface_temperature': 90.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 3, 3, 58, 14),
#              'confidence': 88.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 3, 3, 58, 14),
#              'confidence': 87.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 4, 4, 41, 2),
#              'confidence': 80.0,
#              'surface_temperature': 46.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 4, 4, 41),
#              'confidence': 80.0,
#              'surface_temperature': 46.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 4, 4, 41),
#              'confidence': 85.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 4, 4, 41),
#              'confidence': 88.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 19.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 7, 12, 59, 33),
#              'confidence': 91.0,
#              'surface_temperature': 42.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 10, 4, 4, 19),
#              'confidence': 96.0,
#              'surface_temperature': 77.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 15, 4, 23, 1),
#              'confidence': 100.0,
#              'surface_temperature': 87.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 15, 4, 23, 1),
#              'confidence': 99.0,
#              'surface_temperature': 85.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 17, 13, 36, 12),
#              'confidence': 94.0,
#              'surface_temperature': 43.0},
#  'air_temperature': 22.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 17, 4, 10, 45),
#              'confidence': 91.0,
#              'surface_temperature': 68.0},
#  'air_temperature': 22.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 17, 4, 10, 32),
#              'confidence': 82.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 22.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 18, 0, 39, 2),
#              'confidence': 84.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 18, 0, 39, 2),
#              'confidence': 82.0,
#              'surface_temperature': 56.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 20, 4, 41, 19),
#              'confidence': 80.0,
#              'surface_temperature': 46.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 20, 4, 41, 19),
#              'confidence': 82.0,
#              'surface_temperature': 50.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 21, 1, 9, 55),
#              'confidence': 88.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 12.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 21, 1, 9, 54),
#              'confidence': 92.0,
#              'surface_temperature': 67.0},
#  'air_temperature': 12.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 26, 13, 30, 31),
#              'confidence': 100.0,
#              'surface_temperature': 48.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 26, 13, 30, 31),
#              'confidence': 100.0,
#              'surface_temperature': 53.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 27, 4, 47, 31),
#              'confidence': 86.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 22.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 10, 28, 3, 52, 17),
#              'confidence': 81.0,
#              'surface_temperature': 56.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 5, 4, 41, 34),
#              'confidence': 83.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 5, 4, 41, 19),
#              'confidence': 90.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 5, 4, 41, 19),
#              'confidence': 89.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 13.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 9, 4, 16, 48),
#              'confidence': 85.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 9, 4, 16, 48),
#              'confidence': 100.0,
#              'surface_temperature': 93.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 9, 4, 16, 48),
#              'confidence': 96.0,
#              'surface_temperature': 77.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 9, 4, 16, 44),
#              'confidence': 87.0,
#              'surface_temperature': 62.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 9, 4, 16, 44),
#              'confidence': 97.0,
#              'surface_temperature': 80.0},
#  'air_temperature': 14.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 11, 13, 30, 8),
#              'confidence': 80.0,
#              'surface_temperature': 37.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 11, 13, 30, 8),
#              'confidence': 100.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 11, 4, 4, 25),
#              'confidence': 86.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 12, 0, 33, 15),
#              'confidence': 89.0,
#              'surface_temperature': 69.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 13, 3, 52, 15),
#              'confidence': 87.0,
#              'surface_temperature': 61.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 13, 3, 52, 14),
#              'confidence': 81.0,
#              'surface_temperature': 53.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 14, 4, 35, 4),
#              'confidence': 87.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 28.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 21, 0, 27, 21),
#              'confidence': 85.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 22, 3, 46),
#              'confidence': 84.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 22, 3, 46),
#              'confidence': 88.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 23.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 23, 4, 28, 59),
#              'confidence': 84.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 23, 4, 28, 59),
#              'confidence': 93.0,
#              'surface_temperature': 73.0},
#  'air_temperature': 24.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 29, 13, 17, 24),
#              'confidence': 100.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 28.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#              'confidence': 100.0,
#              'surface_temperature': 87.0},
#  'air_temperature': 28.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#              'confidence': 97.0,
#              'surface_temperature': 80.0},
#  'air_temperature': 28.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#              'confidence': 99.0,
#              'surface_temperature': 84.0},
#  'air_temperature': 28.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#              'confidence': 100.0,
#              'surface_temperature': 53.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#              'confidence': 100.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#              'confidence': 100.0,
#              'surface_temperature': 49.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#              'confidence': 84.0,
#              'surface_temperature': 38.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#              'confidence': 81.0,
#              'surface_temperature': 42.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#              'confidence': 100.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#              'confidence': 100.0,
#              'surface_temperature': 65.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 12, 22, 14),
#              'confidence': 100.0,
#              'surface_temperature': 71.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 4, 35),
#              'confidence': 84.0,
#              'surface_temperature': 59.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#              'confidence': 98.0,
#              'surface_temperature': 83.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#              'confidence': 81.0,
#              'surface_temperature': 57.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#              'confidence': 84.0,
#              'surface_temperature': 61.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#              'confidence': 99.0,
#              'surface_temperature': 86.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#              'confidence': 83.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#              'confidence': 87.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#              'confidence': 95.0,
#              'surface_temperature': 76.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#              'confidence': 81.0,
#              'surface_temperature': 56.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#              'confidence': 81.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 26.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 8, 13, 11, 44),
#              'confidence': 100.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 8, 13, 11, 44),
#              'confidence': 100.0,
#              'surface_temperature': 71.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 8, 13, 11, 43),
#              'confidence': 100.0,
#              'surface_temperature': 52.0},
#  'air_temperature': 15.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 9, 0, 14, 34),
#              'confidence': 87.0,
#              'surface_temperature': 61.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 9, 0, 14, 34),
#              'confidence': 81.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 9, 0, 14, 33),
#              'confidence': 84.0,
#              'surface_temperature': 58.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 9, 0, 14, 33),
#              'confidence': 86.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 13, 4, 4, 19),
#              'confidence': 83.0,
#              'surface_temperature': 60.0},
#  'air_temperature': 28.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 14, 4, 47, 25),
#              'confidence': 92.0,
#              'surface_temperature': 70.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 15, 13, 17, 17),
#              'confidence': 92.0,
#              'surface_temperature': 42.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 16, 15, 38, 39),
#              'confidence': 94.0,
#              'surface_temperature': 43.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 16, 4, 35, 13),
#              'confidence': 93.0,
#              'surface_temperature': 73.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 16, 4, 34, 58),
#              'confidence': 84.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 16, 4, 34, 58),
#              'confidence': 95.0,
#              'surface_temperature': 75.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#              'confidence': 90.0,
#              'surface_temperature': 66.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 16, 0, 21, 12),
#              'confidence': 93.0,
#              'surface_temperature': 73.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 16, 0, 21, 11),
#              'confidence': 82.0,
#              'surface_temperature': 55.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 16, 0, 20, 53),
#              'confidence': 82.0,
#              'surface_temperature': 64.0},
#  'air_temperature': 18.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 25, 4, 29, 8),
#              'confidence': 80.0,
#              'surface_temperature': 54.0},
#  'air_temperature': 17.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 27, 0, 2, 15),
#              'confidence': 82.0,
#              'surface_temperature': 63.0},
#  'air_temperature': 28.0}
#
# {'hotspot': {'datetime': datetime.datetime(2022, 12, 27, 0, 2, 14),
#              'confidence': 86.0,
#              'surface_temperature': 67.0},
#  'air_temperature': 28.0}

# %% [markdown]
# e) Find the top 10 records with the highest surface temperature (°C).

# %%
response = fire_collection.aggregate([
    {'$unwind':'$hotspot'},
    {'$sort':{'hotspot.surface_temperature':-1}},
    {'$limit':10}
    ])

# %%
print_response(response)
# Out:
# {'_id': ObjectId('64809ea999470914613d9f35'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 4, 18, 0, 0),
#  'hotspot': {'longitude': 143.062,
#              'latitude': -38.1665,
#              'datetime': datetime.datetime(2022, 4, 18, 4, 52),
#              'confidence': 100.0,
#              'surface_temperature': 124.0},
#  'air_temperature': 15.0,
#  'relative_humidity': 56.1,
#  'windspeed_knots': 5.1,
#  'max_wind_speed': 9.9,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 122.0}
#
# {'_id': ObjectId('64809ea999470914613d9f27'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 142.1986,
#              'latitude': -36.343,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#              'confidence': 100.0,
#              'surface_temperature': 123.0},
#  'air_temperature': 16.0,
#  'relative_humidity': 47.5,
#  'windspeed_knots': 5.4,
#  'max_wind_speed': 12.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 140.0}
#
# {'_id': ObjectId('64809ea999470914613d9f42'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 5, 1, 0, 0),
#  'hotspot': {'longitude': 143.0907,
#              'latitude': -36.9318,
#              'datetime': datetime.datetime(2022, 5, 1, 4, 14, 20),
#              'confidence': 100.0,
#              'surface_temperature': 122.0},
#  'air_temperature': 14.0,
#  'relative_humidity': 49.2,
#  'windspeed_knots': 10.5,
#  'max_wind_speed': 20.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.12,
#  'GHI': 121.0}
#
# {'_id': ObjectId('64809ea999470914613d9f16'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 3, 18, 0, 0),
#  'hotspot': {'longitude': 148.1297,
#              'latitude': -37.017,
#              'datetime': datetime.datetime(2022, 3, 18, 3, 50, 50),
#              'confidence': 100.0,
#              'surface_temperature': 121.0},
#  'air_temperature': 21.0,
#  'relative_humidity': 52.8,
#  'windspeed_knots': 4.1,
#  'max_wind_speed': 11.1,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 176.0}
#
# {'_id': ObjectId('64809ea999470914613d9f27'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 142.2008,
#              'latitude': -36.3521,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 100.0,
#              'surface_temperature': 120.0},
#  'air_temperature': 16.0,
#  'relative_humidity': 47.5,
#  'windspeed_knots': 5.4,
#  'max_wind_speed': 12.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 140.0}
#
# {'_id': ObjectId('64809ea999470914613d9f30'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 4, 13, 0, 0),
#  'hotspot': {'longitude': 141.0692,
#              'latitude': -37.0745,
#              'datetime': datetime.datetime(2022, 4, 13, 4, 28, 10),
#              'confidence': 100.0,
#              'surface_temperature': 120.0},
#  'air_temperature': 16.0,
#  'relative_humidity': 54.9,
#  'windspeed_knots': 5.9,
#  'max_wind_speed': 9.9,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 132.0}
#
# {'_id': ObjectId('64809ea999470914613d9f4e'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 5, 13, 0, 0),
#  'hotspot': {'longitude': 141.876,
#              'latitude': -34.9938,
#              'datetime': datetime.datetime(2022, 5, 13, 4, 40, 20),
#              'confidence': 100.0,
#              'surface_temperature': 120.0},
#  'air_temperature': 9.0,
#  'relative_humidity': 44.0,
#  'windspeed_knots': 2.8,
#  'max_wind_speed': 8.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 81.0}
#
# {'_id': ObjectId('64809ea999470914613d9f35'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 4, 18, 0, 0),
#  'hotspot': {'longitude': 143.4999,
#              'latitude': -37.8326,
#              'datetime': datetime.datetime(2022, 4, 18, 4, 44, 50),
#              'confidence': 100.0,
#              'surface_temperature': 120.0},
#  'air_temperature': 15.0,
#  'relative_humidity': 56.1,
#  'windspeed_knots': 5.1,
#  'max_wind_speed': 9.9,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 122.0}
#
# {'_id': ObjectId('64809ea999470914613d9f27'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 141.7608,
#              'latitude': -36.1057,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 40),
#              'confidence': 100.0,
#              'surface_temperature': 120.0},
#  'air_temperature': 16.0,
#  'relative_humidity': 47.5,
#  'windspeed_knots': 5.4,
#  'max_wind_speed': 12.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 140.0}
#
# {'_id': ObjectId('64809ea999470914613d9f45'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 5, 4, 0, 0),
#  'hotspot': {'longitude': 140.9806,
#              'latitude': -36.4057,
#              'datetime': datetime.datetime(2022, 5, 4, 4, 44, 50),
#              'confidence': 100.0,
#              'surface_temperature': 119.0},
#  'air_temperature': 10.0,
#  'relative_humidity': 43.3,
#  'windspeed_knots': 2.6,
#  'max_wind_speed': 7.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 91.0}

# %% [markdown]
# f) Find the number of fires each day. You are required to only display the total number of fires and the date in the output.

# %%
response = fire_collection.aggregate([
    {'$project':{'_id':0, 'date':1, 'num_of_fires':{'$size':'$hotspot'}}},
    {'$group':{'_id':'$date', 'num_of_fires':{'$sum':'$num_of_fires'}}},
    {'$project':{'_id':0, 'date': '$_id', 'num_of_fires':1}},
    {'$sort':{'date':1}}
])

# %%
print_response(response)
# Out:
# {'num_of_fires': 0, 'date': datetime.datetime(2021, 12, 31, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 2, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 3, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 4, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 5, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 6, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 7, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 8, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 9, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 10, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 11, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 12, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 13, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 14, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 15, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 16, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 17, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 18, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 19, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 20, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 21, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 22, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 23, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 24, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 25, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 26, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 27, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 28, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 29, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 30, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 1, 31, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 1, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 2, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 3, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 4, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 5, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 6, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 7, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 8, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 9, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 10, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 11, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 12, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 13, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 14, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 15, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 16, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 17, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 18, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 19, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 20, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 21, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 22, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 23, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 24, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 25, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 26, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 27, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 2, 28, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 1, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 2, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 3, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 4, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 5, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 3, 6, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 3, 7, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 3, 8, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 3, 9, 0, 0)}
#
# {'num_of_fires': 8, 'date': datetime.datetime(2022, 3, 10, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 11, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 3, 12, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 3, 13, 0, 0)}
#
# {'num_of_fires': 10, 'date': datetime.datetime(2022, 3, 14, 0, 0)}
#
# {'num_of_fires': 7, 'date': datetime.datetime(2022, 3, 15, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 16, 0, 0)}
#
# {'num_of_fires': 6, 'date': datetime.datetime(2022, 3, 17, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 3, 18, 0, 0)}
#
# {'num_of_fires': 21, 'date': datetime.datetime(2022, 3, 19, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 20, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 21, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 22, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 23, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 3, 24, 0, 0)}
#
# {'num_of_fires': 13, 'date': datetime.datetime(2022, 3, 25, 0, 0)}
#
# {'num_of_fires': 17, 'date': datetime.datetime(2022, 3, 26, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 27, 0, 0)}
#
# {'num_of_fires': 54, 'date': datetime.datetime(2022, 3, 28, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 3, 29, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 3, 30, 0, 0)}
#
# {'num_of_fires': 22, 'date': datetime.datetime(2022, 3, 31, 0, 0)}
#
# {'num_of_fires': 7, 'date': datetime.datetime(2022, 4, 1, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 4, 2, 0, 0)}
#
# {'num_of_fires': 72, 'date': datetime.datetime(2022, 4, 3, 0, 0)}
#
# {'num_of_fires': 89, 'date': datetime.datetime(2022, 4, 4, 0, 0)}
#
# {'num_of_fires': 49, 'date': datetime.datetime(2022, 4, 5, 0, 0)}
#
# {'num_of_fires': 118, 'date': datetime.datetime(2022, 4, 6, 0, 0)}
#
# {'num_of_fires': 39, 'date': datetime.datetime(2022, 4, 7, 0, 0)}
#
# {'num_of_fires': 20, 'date': datetime.datetime(2022, 4, 8, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 4, 9, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 4, 10, 0, 0)}
#
# {'num_of_fires': 24, 'date': datetime.datetime(2022, 4, 11, 0, 0)}
#
# {'num_of_fires': 69, 'date': datetime.datetime(2022, 4, 12, 0, 0)}
#
# {'num_of_fires': 357, 'date': datetime.datetime(2022, 4, 13, 0, 0)}
#
# {'num_of_fires': 18, 'date': datetime.datetime(2022, 4, 14, 0, 0)}
#
# {'num_of_fires': 69, 'date': datetime.datetime(2022, 4, 15, 0, 0)}
#
# {'num_of_fires': 18, 'date': datetime.datetime(2022, 4, 16, 0, 0)}
#
# {'num_of_fires': 38, 'date': datetime.datetime(2022, 4, 17, 0, 0)}
#
# {'num_of_fires': 325, 'date': datetime.datetime(2022, 4, 18, 0, 0)}
#
# {'num_of_fires': 50, 'date': datetime.datetime(2022, 4, 19, 0, 0)}
#
# {'num_of_fires': 31, 'date': datetime.datetime(2022, 4, 20, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 4, 21, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 4, 22, 0, 0)}
#
# {'num_of_fires': 19, 'date': datetime.datetime(2022, 4, 23, 0, 0)}
#
# {'num_of_fires': 8, 'date': datetime.datetime(2022, 4, 24, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 4, 25, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 4, 26, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 4, 27, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 4, 28, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 4, 29, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 4, 30, 0, 0)}
#
# {'num_of_fires': 20, 'date': datetime.datetime(2022, 5, 1, 0, 0)}
#
# {'num_of_fires': 10, 'date': datetime.datetime(2022, 5, 2, 0, 0)}
#
# {'num_of_fires': 64, 'date': datetime.datetime(2022, 5, 3, 0, 0)}
#
# {'num_of_fires': 135, 'date': datetime.datetime(2022, 5, 4, 0, 0)}
#
# {'num_of_fires': 31, 'date': datetime.datetime(2022, 5, 5, 0, 0)}
#
# {'num_of_fires': 17, 'date': datetime.datetime(2022, 5, 6, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 5, 7, 0, 0)}
#
# {'num_of_fires': 24, 'date': datetime.datetime(2022, 5, 8, 0, 0)}
#
# {'num_of_fires': 13, 'date': datetime.datetime(2022, 5, 9, 0, 0)}
#
# {'num_of_fires': 114, 'date': datetime.datetime(2022, 5, 10, 0, 0)}
#
# {'num_of_fires': 19, 'date': datetime.datetime(2022, 5, 11, 0, 0)}
#
# {'num_of_fires': 10, 'date': datetime.datetime(2022, 5, 12, 0, 0)}
#
# {'num_of_fires': 54, 'date': datetime.datetime(2022, 5, 13, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 5, 14, 0, 0)}
#
# {'num_of_fires': 102, 'date': datetime.datetime(2022, 5, 15, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 5, 16, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 5, 17, 0, 0)}
#
# {'num_of_fires': 7, 'date': datetime.datetime(2022, 5, 18, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 5, 19, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 5, 20, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 5, 21, 0, 0)}
#
# {'num_of_fires': 33, 'date': datetime.datetime(2022, 5, 22, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 5, 23, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 5, 24, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 5, 25, 0, 0)}
#
# {'num_of_fires': 4, 'date': datetime.datetime(2022, 5, 26, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 5, 27, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 5, 28, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 5, 29, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 5, 30, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 5, 31, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 6, 1, 0, 0)}
#
# {'num_of_fires': 11, 'date': datetime.datetime(2022, 6, 2, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 6, 3, 0, 0)}
#
# {'num_of_fires': 9, 'date': datetime.datetime(2022, 6, 4, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 5, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 6, 0, 0)}
#
# {'num_of_fires': 14, 'date': datetime.datetime(2022, 6, 7, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 8, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 6, 9, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 10, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 6, 11, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 12, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 6, 13, 0, 0)}
#
# {'num_of_fires': 4, 'date': datetime.datetime(2022, 6, 14, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 15, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 6, 16, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 17, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 6, 18, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 19, 0, 0)}
#
# {'num_of_fires': 6, 'date': datetime.datetime(2022, 6, 20, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 21, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 6, 22, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 23, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 24, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 25, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 26, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 27, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 28, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 6, 29, 0, 0)}
#
# {'num_of_fires': 6, 'date': datetime.datetime(2022, 6, 30, 0, 0)}
#
# {'num_of_fires': 4, 'date': datetime.datetime(2022, 7, 1, 0, 0)}
#
# {'num_of_fires': 8, 'date': datetime.datetime(2022, 7, 2, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 3, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 7, 4, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 7, 5, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 7, 6, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 7, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 8, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 9, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 10, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 11, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 12, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 13, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 7, 14, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 15, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 16, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 17, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 18, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 19, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 20, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 21, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 22, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 23, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 24, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 25, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 26, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 27, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 28, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 7, 29, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 7, 30, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 7, 31, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 8, 1, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 8, 2, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 3, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 4, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 8, 5, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 6, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 7, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 8, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 9, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 8, 10, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 11, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 12, 0, 0)}
#
# {'num_of_fires': 9, 'date': datetime.datetime(2022, 8, 13, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 8, 14, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 15, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 16, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 17, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 18, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 19, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 20, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 21, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 22, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 23, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 24, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 25, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 26, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 27, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 28, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 29, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 30, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 8, 31, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 1, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 2, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 3, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 4, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 5, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 6, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 7, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 8, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 9, 0, 0)}
#
# {'num_of_fires': 4, 'date': datetime.datetime(2022, 9, 10, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 11, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 12, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 13, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 14, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 15, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 16, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 17, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 18, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 19, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 9, 20, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 9, 21, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 9, 22, 0, 0)}
#
# {'num_of_fires': 23, 'date': datetime.datetime(2022, 9, 23, 0, 0)}
#
# {'num_of_fires': 28, 'date': datetime.datetime(2022, 9, 24, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 25, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 9, 26, 0, 0)}
#
# {'num_of_fires': 7, 'date': datetime.datetime(2022, 9, 27, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 28, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 9, 29, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 9, 30, 0, 0)}
#
# {'num_of_fires': 8, 'date': datetime.datetime(2022, 10, 1, 0, 0)}
#
# {'num_of_fires': 7, 'date': datetime.datetime(2022, 10, 2, 0, 0)}
#
# {'num_of_fires': 18, 'date': datetime.datetime(2022, 10, 3, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 10, 4, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 5, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 10, 6, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 10, 7, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 10, 8, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 10, 9, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 10, 10, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 11, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 12, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 13, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 14, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 10, 15, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 10, 16, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 10, 17, 0, 0)}
#
# {'num_of_fires': 6, 'date': datetime.datetime(2022, 10, 18, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 19, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 10, 20, 0, 0)}
#
# {'num_of_fires': 4, 'date': datetime.datetime(2022, 10, 21, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 22, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 10, 23, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 24, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 25, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 10, 26, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 10, 27, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 10, 28, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 29, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 30, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 10, 31, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 1, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 2, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 3, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 4, 0, 0)}
#
# {'num_of_fires': 4, 'date': datetime.datetime(2022, 11, 5, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 6, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 7, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 11, 8, 0, 0)}
#
# {'num_of_fires': 10, 'date': datetime.datetime(2022, 11, 9, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 10, 0, 0)}
#
# {'num_of_fires': 4, 'date': datetime.datetime(2022, 11, 11, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 11, 12, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 11, 13, 0, 0)}
#
# {'num_of_fires': 3, 'date': datetime.datetime(2022, 11, 14, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 15, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 16, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 17, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 18, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 19, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 20, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 11, 21, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 11, 22, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 11, 23, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 24, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 25, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 26, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 11, 27, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 11, 28, 0, 0)}
#
# {'num_of_fires': 8, 'date': datetime.datetime(2022, 11, 29, 0, 0)}
#
# {'num_of_fires': 31, 'date': datetime.datetime(2022, 11, 30, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 1, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 2, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 3, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 4, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 5, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 6, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 7, 0, 0)}
#
# {'num_of_fires': 5, 'date': datetime.datetime(2022, 12, 8, 0, 0)}
#
# {'num_of_fires': 4, 'date': datetime.datetime(2022, 12, 9, 0, 0)}
#
# {'num_of_fires': 2, 'date': datetime.datetime(2022, 12, 10, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 11, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 12, 12, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 12, 13, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 12, 14, 0, 0)}
#
# {'num_of_fires': 4, 'date': datetime.datetime(2022, 12, 15, 0, 0)}
#
# {'num_of_fires': 15, 'date': datetime.datetime(2022, 12, 16, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 17, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 18, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 19, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 20, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 12, 21, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 22, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 23, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 12, 24, 0, 0)}
#
# {'num_of_fires': 1, 'date': datetime.datetime(2022, 12, 25, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 26, 0, 0)}
#
# {'num_of_fires': 4, 'date': datetime.datetime(2022, 12, 27, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 28, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 29, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 30, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2022, 12, 31, 0, 0)}
#
# {'num_of_fires': 0, 'date': datetime.datetime(2023, 1, 1, 0, 0)}

# %% [markdown]
# g) Find the records of fires where the confidence is below 70.

# %%
response = fire_collection.aggregate([
    {'$unwind':'$hotspot'},
    {'$match':{'hotspot.confidence':{'$lt':70}}},
    {'$project':{
        '_id':0,
        'hotspot':1,
        'date':1
    }}
])

# %%
print_response(response)
# Out:
# {'date': datetime.datetime(2022, 3, 8, 0, 0),
#  'hotspot': {'longitude': 141.9352,
#              'latitude': -37.7885,
#              'datetime': datetime.datetime(2022, 3, 8, 4, 51),
#              'confidence': 68.0,
#              'surface_temperature': 55.0}}
#
# {'date': datetime.datetime(2022, 3, 9, 0, 0),
#  'hotspot': {'longitude': 147.5866,
#              'latitude': -37.7171,
#              'datetime': datetime.datetime(2022, 3, 9, 3, 57),
#              'confidence': 54.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 3, 10, 0, 0),
#  'hotspot': {'longitude': 148.0353,
#              'latitude': -36.2544,
#              'datetime': datetime.datetime(2022, 3, 10, 4, 43),
#              'confidence': 55.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 3, 10, 0, 0),
#  'hotspot': {'longitude': 147.9621,
#              'latitude': -37.2197,
#              'datetime': datetime.datetime(2022, 3, 10, 4, 42, 30),
#              'confidence': 54.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 3, 13, 0, 0),
#  'hotspot': {'longitude': 148.155,
#              'latitude': -37.0286,
#              'datetime': datetime.datetime(2022, 3, 13, 23, 58, 50),
#              'confidence': 56.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 3, 13, 0, 0),
#  'hotspot': {'longitude': 148.1519,
#              'latitude': -37.0316,
#              'datetime': datetime.datetime(2022, 3, 13, 12, 57),
#              'confidence': 52.0,
#              'surface_temperature': 35.0}}
#
# {'date': datetime.datetime(2022, 3, 15, 0, 0),
#  'hotspot': {'longitude': 147.0233,
#              'latitude': -37.4075,
#              'datetime': datetime.datetime(2022, 3, 15, 0, 42, 50),
#              'confidence': 52.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 3, 15, 0, 0),
#  'hotspot': {'longitude': 148.1281,
#              'latitude': -37.0228,
#              'datetime': datetime.datetime(2022, 3, 15, 0, 42, 50),
#              'confidence': 66.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 3, 15, 0, 0),
#  'hotspot': {'longitude': 148.2055,
#              'latitude': -37.002,
#              'datetime': datetime.datetime(2022, 3, 15, 0, 42, 40),
#              'confidence': 51.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 3, 18, 0, 0),
#  'hotspot': {'longitude': 147.0343,
#              'latitude': -37.4313,
#              'datetime': datetime.datetime(2022, 3, 18, 13, 16, 50),
#              'confidence': 64.0,
#              'surface_temperature': 37.0}}
#
# {'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspot': {'longitude': 143.4866,
#              'latitude': -37.9164,
#              'datetime': datetime.datetime(2022, 3, 19, 4, 39, 20),
#              'confidence': 58.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspot': {'longitude': 143.4891,
#              'latitude': -37.9257,
#              'datetime': datetime.datetime(2022, 3, 19, 4, 39, 20),
#              'confidence': 63.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspot': {'longitude': 147.0001,
#              'latitude': -37.3982,
#              'datetime': datetime.datetime(2022, 3, 19, 4, 36),
#              'confidence': 64.0,
#              'surface_temperature': 58.0}}
#
# {'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspot': {'longitude': 147.0394,
#              'latitude': -37.4023,
#              'datetime': datetime.datetime(2022, 3, 19, 4, 35),
#              'confidence': 59.0,
#              'surface_temperature': 56.0}}
#
# {'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspot': {'longitude': 147.0534,
#              'latitude': -37.4336,
#              'datetime': datetime.datetime(2022, 3, 19, 4, 33, 50),
#              'confidence': 60.0,
#              'surface_temperature': 51.0}}
#
# {'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspot': {'longitude': 147.0448,
#              'latitude': -37.4003,
#              'datetime': datetime.datetime(2022, 3, 19, 4, 33, 30),
#              'confidence': 61.0,
#              'surface_temperature': 55.0}}
#
# {'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspot': {'longitude': 143.4745,
#              'latitude': -37.9184,
#              'datetime': datetime.datetime(2022, 3, 19, 4, 33, 30),
#              'confidence': 53.0,
#              'surface_temperature': 55.0}}
#
# {'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspot': {'longitude': 147.037,
#              'latitude': -37.3911,
#              'datetime': datetime.datetime(2022, 3, 19, 4, 33, 10),
#              'confidence': 61.0,
#              'surface_temperature': 50.0}}
#
# {'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspot': {'longitude': 143.477,
#              'latitude': -37.9277,
#              'datetime': datetime.datetime(2022, 3, 19, 4, 32, 50),
#              'confidence': 66.0,
#              'surface_temperature': 55.0}}
#
# {'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspot': {'longitude': 147.0455,
#              'latitude': -37.3942,
#              'datetime': datetime.datetime(2022, 3, 19, 0, 12, 50),
#              'confidence': 60.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 3, 24, 0, 0),
#  'hotspot': {'longitude': 142.8088,
#              'latitude': -37.1603,
#              'datetime': datetime.datetime(2022, 3, 24, 4, 58),
#              'confidence': 65.0,
#              'surface_temperature': 50.0}}
#
# {'date': datetime.datetime(2022, 3, 24, 0, 0),
#  'hotspot': {'longitude': 142.8183,
#              'latitude': -37.1684,
#              'datetime': datetime.datetime(2022, 3, 24, 4, 56, 10),
#              'confidence': 55.0,
#              'surface_temperature': 48.0}}
#
# {'date': datetime.datetime(2022, 3, 25, 0, 0),
#  'hotspot': {'longitude': 143.4534,
#              'latitude': -37.8992,
#              'datetime': datetime.datetime(2022, 3, 25, 4, 3, 10),
#              'confidence': 62.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 3, 25, 0, 0),
#  'hotspot': {'longitude': 143.4607,
#              'latitude': -37.9022,
#              'datetime': datetime.datetime(2022, 3, 25, 3, 56, 40),
#              'confidence': 57.0,
#              'surface_temperature': 57.0}}
#
# {'date': datetime.datetime(2022, 3, 26, 0, 0),
#  'hotspot': {'longitude': 143.7173,
#              'latitude': -38.1131,
#              'datetime': datetime.datetime(2022, 3, 26, 4, 41, 10),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 3, 26, 0, 0),
#  'hotspot': {'longitude': 143.5343,
#              'latitude': -37.8469,
#              'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#              'confidence': 60.0,
#              'surface_temperature': 50.0}}
#
# {'date': datetime.datetime(2022, 3, 26, 0, 0),
#  'hotspot': {'longitude': 141.0252,
#              'latitude': -37.1956,
#              'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#              'confidence': 67.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 3, 28, 0, 0),
#  'hotspot': {'longitude': 143.4212,
#              'latitude': -37.6195,
#              'datetime': datetime.datetime(2022, 3, 28, 4, 29, 30),
#              'confidence': 53.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 3, 28, 0, 0),
#  'hotspot': {'longitude': 143.4255,
#              'latitude': -37.6376,
#              'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 63.0,
#              'surface_temperature': 48.0}}
#
# {'date': datetime.datetime(2022, 3, 28, 0, 0),
#  'hotspot': {'longitude': 141.4172,
#              'latitude': -36.4422,
#              'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 69.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 3, 28, 0, 0),
#  'hotspot': {'longitude': 141.6548,
#              'latitude': -34.342,
#              'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#              'confidence': 55.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 3, 29, 0, 0),
#  'hotspot': {'longitude': 141.6325,
#              'latitude': -34.2648,
#              'datetime': datetime.datetime(2022, 3, 29, 0, 48, 40),
#              'confidence': 69.0,
#              'surface_temperature': 51.0}}
#
# {'date': datetime.datetime(2022, 3, 31, 0, 0),
#  'hotspot': {'longitude': 145.9352,
#              'latitude': -36.1649,
#              'datetime': datetime.datetime(2022, 3, 31, 4, 57, 50),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 3, 31, 0, 0),
#  'hotspot': {'longitude': 145.7964,
#              'latitude': -36.0436,
#              'datetime': datetime.datetime(2022, 3, 31, 4, 57, 40),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 3, 31, 0, 0),
#  'hotspot': {'longitude': 145.2151,
#              'latitude': -36.7134,
#              'datetime': datetime.datetime(2022, 3, 31, 4, 57, 10),
#              'confidence': 52.0,
#              'surface_temperature': 38.0}}
#
# {'date': datetime.datetime(2022, 3, 31, 0, 0),
#  'hotspot': {'longitude': 145.2519,
#              'latitude': -36.7028,
#              'datetime': datetime.datetime(2022, 3, 31, 4, 57, 10),
#              'confidence': 61.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 3, 31, 0, 0),
#  'hotspot': {'longitude': 143.242,
#              'latitude': -37.561,
#              'datetime': datetime.datetime(2022, 3, 31, 4, 57, 10),
#              'confidence': 51.0,
#              'surface_temperature': 38.0}}
#
# {'date': datetime.datetime(2022, 3, 31, 0, 0),
#  'hotspot': {'longitude': 143.6422,
#              'latitude': -37.982,
#              'datetime': datetime.datetime(2022, 3, 31, 4, 57, 10),
#              'confidence': 56.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 3, 31, 0, 0),
#  'hotspot': {'longitude': 141.64,
#              'latitude': -34.2568,
#              'datetime': datetime.datetime(2022, 3, 31, 0, 36, 30),
#              'confidence': 51.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 1, 0, 0),
#  'hotspot': {'longitude': 145.7706,
#              'latitude': -36.2044,
#              'datetime': datetime.datetime(2022, 4, 1, 4, 2, 40),
#              'confidence': 58.0,
#              'surface_temperature': 51.0}}
#
# {'date': datetime.datetime(2022, 4, 1, 0, 0),
#  'hotspot': {'longitude': 143.1556,
#              'latitude': -36.5245,
#              'datetime': datetime.datetime(2022, 4, 1, 4, 2, 40),
#              'confidence': 57.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 1, 0, 0),
#  'hotspot': {'longitude': 147.6494,
#              'latitude': -36.1002,
#              'datetime': datetime.datetime(2022, 4, 1, 4, 2, 40),
#              'confidence': 50.0,
#              'surface_temperature': 39.0}}
#
# {'date': datetime.datetime(2022, 4, 2, 0, 0),
#  'hotspot': {'longitude': 145.3858,
#              'latitude': -36.3872,
#              'datetime': datetime.datetime(2022, 4, 2, 4, 53, 30),
#              'confidence': 60.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 2, 0, 0),
#  'hotspot': {'longitude': 145.4522,
#              'latitude': -36.494,
#              'datetime': datetime.datetime(2022, 4, 2, 4, 45, 10),
#              'confidence': 63.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 4, 2, 0, 0),
#  'hotspot': {'longitude': 146.1647,
#              'latitude': -37.324,
#              'datetime': datetime.datetime(2022, 4, 2, 0, 24, 50),
#              'confidence': 60.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 143.0472,
#              'latitude': -37.8668,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 53, 50),
#              'confidence': 69.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 143.382,
#              'latitude': -37.7602,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 53, 40),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 142.9509,
#              'latitude': -37.7885,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 53, 30),
#              'confidence': 66.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 143.2566,
#              'latitude': -37.8717,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 52, 10),
#              'confidence': 66.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 144.7343,
#              'latitude': -37.8011,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 51, 10),
#              'confidence': 67.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 141.5163,
#              'latitude': -37.0241,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#              'confidence': 67.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 143.543,
#              'latitude': -37.2912,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#              'confidence': 66.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 146.1561,
#              'latitude': -37.313,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#              'confidence': 52.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 143.6739,
#              'latitude': -38.0226,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#              'confidence': 56.0,
#              'surface_temperature': 39.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 145.9555,
#              'latitude': -37.8089,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 56.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 143.6217,
#              'latitude': -37.9009,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 62.0,
#              'surface_temperature': 45.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 142.9437,
#              'latitude': -37.7836,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 69.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 141.6245,
#              'latitude': -37.0484,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 52.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 142.1445,
#              'latitude': -36.911,
#              'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#              'confidence': 68.0,
#              'surface_temperature': 47.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 141.6199,
#              'latitude': -34.2536,
#              'datetime': datetime.datetime(2022, 4, 3, 1, 11),
#              'confidence': 67.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 4, 3, 0, 0),
#  'hotspot': {'longitude': 141.6412,
#              'latitude': -34.2614,
#              'datetime': datetime.datetime(2022, 4, 3, 1, 7),
#              'confidence': 57.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 141.7154,
#              'latitude': -36.0933,
#              'datetime': datetime.datetime(2022, 4, 4, 15, 30, 40),
#              'confidence': 63.0,
#              'surface_temperature': 35.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 142.4349,
#              'latitude': -36.6281,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 39, 50),
#              'confidence': 64.0,
#              'surface_temperature': 68.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 142.1176,
#              'latitude': -36.937,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 39, 40),
#              'confidence': 61.0,
#              'surface_temperature': 50.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 145.424,
#              'latitude': -36.6951,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 38, 10),
#              'confidence': 50.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 144.2154,
#              'latitude': -37.6714,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 36, 30),
#              'confidence': 67.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 143.9141,
#              'latitude': -38.0494,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 36, 30),
#              'confidence': 63.0,
#              'surface_temperature': 58.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 143.9971,
#              'latitude': -38.4879,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 34, 20),
#              'confidence': 54.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 143.9256,
#              'latitude': -37.1744,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 33, 30),
#              'confidence': 63.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 142.2465,
#              'latitude': -36.4918,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 33, 30),
#              'confidence': 69.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 142.4234,
#              'latitude': -36.6299,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 33, 10),
#              'confidence': 66.0,
#              'surface_temperature': 71.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 145.832,
#              'latitude': -36.1439,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 33, 10),
#              'confidence': 53.0,
#              'surface_temperature': 50.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 141.541,
#              'latitude': -36.7009,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#              'confidence': 54.0,
#              'surface_temperature': 49.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 143.146,
#              'latitude': -36.4611,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 55.0,
#              'surface_temperature': 48.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 142.1894,
#              'latitude': -36.3539,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 53.0,
#              'surface_temperature': 53.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 141.7654,
#              'latitude': -37.0081,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 66.0,
#              'surface_temperature': 62.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 141.7692,
#              'latitude': -36.2889,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 64.0,
#              'surface_temperature': 51.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 142.428,
#              'latitude': -36.6228,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 67.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspot': {'longitude': 143.6409,
#              'latitude': -38.1177,
#              'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#              'confidence': 60.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 147.033,
#              'latitude': -38.3499,
#              'datetime': datetime.datetime(2022, 4, 5, 13, 10, 10),
#              'confidence': 61.0,
#              'surface_temperature': 35.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 146.1417,
#              'latitude': -37.6435,
#              'datetime': datetime.datetime(2022, 4, 5, 13, 2, 40),
#              'confidence': 66.0,
#              'surface_temperature': 36.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 142.3183,
#              'latitude': -37.7522,
#              'datetime': datetime.datetime(2022, 4, 5, 5, 15, 40),
#              'confidence': 66.0,
#              'surface_temperature': 50.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 141.9303,
#              'latitude': -36.9396,
#              'datetime': datetime.datetime(2022, 4, 5, 5, 15, 30),
#              'confidence': 66.0,
#              'surface_temperature': 45.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 141.8091,
#              'latitude': -37.78,
#              'datetime': datetime.datetime(2022, 4, 5, 3, 45, 10),
#              'confidence': 65.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 141.8127,
#              'latitude': -37.7767,
#              'datetime': datetime.datetime(2022, 4, 5, 3, 44, 40),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 143.9829,
#              'latitude': -38.1756,
#              'datetime': datetime.datetime(2022, 4, 5, 3, 44, 30),
#              'confidence': 65.0,
#              'surface_temperature': 53.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 147.0231,
#              'latitude': -38.3553,
#              'datetime': datetime.datetime(2022, 4, 5, 3, 40, 30),
#              'confidence': 50.0,
#              'surface_temperature': 38.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 142.5759,
#              'latitude': -36.934,
#              'datetime': datetime.datetime(2022, 4, 5, 3, 40, 30),
#              'confidence': 64.0,
#              'surface_temperature': 47.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 144.4307,
#              'latitude': -38.0383,
#              'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#              'confidence': 59.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 142.5807,
#              'latitude': -36.9354,
#              'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#              'confidence': 69.0,
#              'surface_temperature': 45.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 142.8627,
#              'latitude': -36.9405,
#              'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 5, 0, 0),
#  'hotspot': {'longitude': 143.4108,
#              'latitude': -37.6339,
#              'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#              'confidence': 69.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 142.1573,
#              'latitude': -37.7069,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 25, 40),
#              'confidence': 66.0,
#              'surface_temperature': 53.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 146.5364,
#              'latitude': -36.0834,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 25, 40),
#              'confidence': 50.0,
#              'surface_temperature': 53.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 141.3268,
#              'latitude': -36.3557,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#              'confidence': 62.0,
#              'surface_temperature': 52.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 147.8367,
#              'latitude': -37.6104,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#              'confidence': 62.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 143.647,
#              'latitude': -37.9229,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#              'confidence': 64.0,
#              'surface_temperature': 63.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 142.8636,
#              'latitude': -37.5052,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#              'confidence': 62.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 142.9168,
#              'latitude': -37.8177,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#              'confidence': 51.0,
#              'surface_temperature': 50.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 148.5717,
#              'latitude': -37.5842,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 21, 20),
#              'confidence': 65.0,
#              'surface_temperature': 49.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 143.8976,
#              'latitude': -38.0089,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 21),
#              'confidence': 64.0,
#              'surface_temperature': 45.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 147.5003,
#              'latitude': -37.3072,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 21),
#              'confidence': 58.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 146.1085,
#              'latitude': -37.3556,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 50),
#              'confidence': 50.0,
#              'surface_temperature': 47.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 143.2676,
#              'latitude': -37.6806,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 59.0,
#              'surface_temperature': 51.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 145.9754,
#              'latitude': -37.7212,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 58.0,
#              'surface_temperature': 52.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 143.8644,
#              'latitude': -38.3343,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 59.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 142.063,
#              'latitude': -35.723,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 64.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 141.8172,
#              'latitude': -35.1383,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 50.0,
#              'surface_temperature': 53.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 141.0286,
#              'latitude': -36.4133,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 52.0,
#              'surface_temperature': 47.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 142.3976,
#              'latitude': -36.6492,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 66.0,
#              'surface_temperature': 60.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 146.4896,
#              'latitude': -36.0765,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 69.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 146.529,
#              'latitude': -36.0799,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 57.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 142.5802,
#              'latitude': -36.8632,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 60.0,
#              'surface_temperature': 60.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 143.8132,
#              'latitude': -37.1929,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 59.0,
#              'surface_temperature': 45.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 146.2301,
#              'latitude': -37.1992,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 68.0,
#              'surface_temperature': 60.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 148.5807,
#              'latitude': -37.5914,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 63.0,
#              'surface_temperature': 61.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 148.3898,
#              'latitude': -37.7496,
#              'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#              'confidence': 64.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 143.1486,
#              'latitude': -35.4625,
#              'datetime': datetime.datetime(2022, 4, 6, 0, 3, 50),
#              'confidence': 67.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 6, 0, 0),
#  'hotspot': {'longitude': 146.9603,
#              'latitude': -38.0942,
#              'datetime': datetime.datetime(2022, 4, 6, 0, 1, 40),
#              'confidence': 52.0,
#              'surface_temperature': 39.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 143.1935,
#              'latitude': -35.6961,
#              'datetime': datetime.datetime(2022, 4, 7, 12, 53, 40),
#              'confidence': 61.0,
#              'surface_temperature': 35.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 149.1283,
#              'latitude': -37.3314,
#              'datetime': datetime.datetime(2022, 4, 7, 12, 52, 10),
#              'confidence': 65.0,
#              'surface_temperature': 35.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 149.3816,
#              'latitude': -37.3359,
#              'datetime': datetime.datetime(2022, 4, 7, 12, 51, 20),
#              'confidence': 51.0,
#              'surface_temperature': 48.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 149.3972,
#              'latitude': -37.3526,
#              'datetime': datetime.datetime(2022, 4, 7, 12, 51),
#              'confidence': 66.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 149.3933,
#              'latitude': -37.3344,
#              'datetime': datetime.datetime(2022, 4, 7, 12, 50, 40),
#              'confidence': 68.0,
#              'surface_temperature': 47.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 149.4088,
#              'latitude': -37.3511,
#              'datetime': datetime.datetime(2022, 4, 7, 12, 50, 40),
#              'confidence': 61.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 147.1254,
#              'latitude': -36.7508,
#              'datetime': datetime.datetime(2022, 4, 7, 12, 50, 40),
#              'confidence': 66.0,
#              'surface_temperature': 39.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 143.0782,
#              'latitude': -36.1031,
#              'datetime': datetime.datetime(2022, 4, 7, 5, 3, 10),
#              'confidence': 63.0,
#              'surface_temperature': 45.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 143.0825,
#              'latitude': -36.1025,
#              'datetime': datetime.datetime(2022, 4, 7, 5, 3, 10),
#              'confidence': 66.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 141.8698,
#              'latitude': -36.7314,
#              'datetime': datetime.datetime(2022, 4, 7, 5, 3, 10),
#              'confidence': 67.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 148.385,
#              'latitude': -37.7931,
#              'datetime': datetime.datetime(2022, 4, 7, 3, 31, 40),
#              'confidence': 64.0,
#              'surface_temperature': 58.0}}
#
# {'date': datetime.datetime(2022, 4, 7, 0, 0),
#  'hotspot': {'longitude': 148.5498,
#              'latitude': -37.7974,
#              'datetime': datetime.datetime(2022, 4, 7, 3, 27, 50),
#              'confidence': 60.0,
#              'surface_temperature': 53.0}}
#
# {'date': datetime.datetime(2022, 4, 8, 0, 0),
#  'hotspot': {'longitude': 149.3668,
#              'latitude': -37.34,
#              'datetime': datetime.datetime(2022, 4, 8, 4, 15, 20),
#              'confidence': 67.0,
#              'surface_temperature': 74.0}}
#
# {'date': datetime.datetime(2022, 4, 8, 0, 0),
#  'hotspot': {'longitude': 147.1576,
#              'latitude': -37.8567,
#              'datetime': datetime.datetime(2022, 4, 8, 4, 14, 40),
#              'confidence': 62.0,
#              'surface_temperature': 48.0}}
#
# {'date': datetime.datetime(2022, 4, 8, 0, 0),
#  'hotspot': {'longitude': 149.1191,
#              'latitude': -37.4368,
#              'datetime': datetime.datetime(2022, 4, 8, 4, 12, 20),
#              'confidence': 56.0,
#              'surface_temperature': 52.0}}
#
# {'date': datetime.datetime(2022, 4, 8, 0, 0),
#  'hotspot': {'longitude': 146.0611,
#              'latitude': -37.9408,
#              'datetime': datetime.datetime(2022, 4, 8, 4, 11, 40),
#              'confidence': 58.0,
#              'surface_temperature': 47.0}}
#
# {'date': datetime.datetime(2022, 4, 8, 0, 0),
#  'hotspot': {'longitude': 146.2162,
#              'latitude': -37.6994,
#              'datetime': datetime.datetime(2022, 4, 8, 4, 9, 20),
#              'confidence': 59.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 8, 0, 0),
#  'hotspot': {'longitude': 142.5844,
#              'latitude': -36.7199,
#              'datetime': datetime.datetime(2022, 4, 8, 4, 8, 50),
#              'confidence': 63.0,
#              'surface_temperature': 56.0}}
#
# {'date': datetime.datetime(2022, 4, 8, 0, 0),
#  'hotspot': {'longitude': 149.3691,
#              'latitude': -37.3493,
#              'datetime': datetime.datetime(2022, 4, 8, 4, 8, 40),
#              'confidence': 66.0,
#              'surface_temperature': 80.0}}
#
# {'date': datetime.datetime(2022, 4, 8, 0, 0),
#  'hotspot': {'longitude': 148.6039,
#              'latitude': -37.6447,
#              'datetime': datetime.datetime(2022, 4, 8, 4, 8, 40),
#              'confidence': 61.0,
#              'surface_temperature': 50.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 145.9074,
#              'latitude': -36.2282,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 50, 20),
#              'confidence': 67.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 146.1402,
#              'latitude': -36.3499,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 42, 10),
#              'confidence': 53.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 145.8846,
#              'latitude': -36.4439,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 40, 30),
#              'confidence': 56.0,
#              'surface_temperature': 39.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 146.5461,
#              'latitude': -36.0818,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 39, 40),
#              'confidence': 57.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 143.3479,
#              'latitude': -36.343,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#              'confidence': 50.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 142.7831,
#              'latitude': -36.1751,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#              'confidence': 67.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 141.0562,
#              'latitude': -36.4606,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#              'confidence': 55.0,
#              'surface_temperature': 39.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 143.2188,
#              'latitude': -36.0156,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#              'confidence': 66.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 141.7793,
#              'latitude': -36.1398,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#              'confidence': 62.0,
#              'surface_temperature': 47.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 143.2912,
#              'latitude': -35.2068,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 146.1268,
#              'latitude': -36.3579,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#              'confidence': 63.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 146.5728,
#              'latitude': -36.0787,
#              'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#              'confidence': 60.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 11, 0, 0),
#  'hotspot': {'longitude': 146.8024,
#              'latitude': -37.9796,
#              'datetime': datetime.datetime(2022, 4, 11, 0, 20, 30),
#              'confidence': 62.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 142.3626,
#              'latitude': -35.4309,
#              'datetime': datetime.datetime(2022, 4, 12, 13, 13, 10),
#              'confidence': 67.0,
#              'surface_temperature': 36.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 142.3644,
#              'latitude': -35.4407,
#              'datetime': datetime.datetime(2022, 4, 12, 13, 9, 20),
#              'confidence': 57.0,
#              'surface_temperature': 35.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 142.6339,
#              'latitude': -37.4755,
#              'datetime': datetime.datetime(2022, 4, 12, 5, 28),
#              'confidence': 67.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 141.4578,
#              'latitude': -36.7453,
#              'datetime': datetime.datetime(2022, 4, 12, 5, 26, 50),
#              'confidence': 54.0,
#              'surface_temperature': 39.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 141.0498,
#              'latitude': -36.7038,
#              'datetime': datetime.datetime(2022, 4, 12, 5, 25),
#              'confidence': 50.0,
#              'surface_temperature': 39.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 142.227,
#              'latitude': -37.7578,
#              'datetime': datetime.datetime(2022, 4, 12, 5, 21, 50),
#              'confidence': 60.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 142.0219,
#              'latitude': -36.8083,
#              'datetime': datetime.datetime(2022, 4, 12, 5, 21, 40),
#              'confidence': 67.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 141.1485,
#              'latitude': -36.714,
#              'datetime': datetime.datetime(2022, 4, 12, 5, 21, 40),
#              'confidence': 61.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 142.5297,
#              'latitude': -36.6385,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 51),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 141.3095,
#              'latitude': -36.9179,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 50, 10),
#              'confidence': 59.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 143.8156,
#              'latitude': -37.3654,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 46, 50),
#              'confidence': 65.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 144.0402,
#              'latitude': -36.6188,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 46, 20),
#              'confidence': 69.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 143.6615,
#              'latitude': -37.4047,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 46),
#              'confidence': 69.0,
#              'surface_temperature': 45.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 141.3998,
#              'latitude': -36.2367,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 46),
#              'confidence': 65.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 144.6939,
#              'latitude': -36.5234,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 45, 10),
#              'confidence': 62.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 141.0957,
#              'latitude': -36.6803,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 45),
#              'confidence': 60.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 142.1989,
#              'latitude': -36.7866,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 50),
#              'confidence': 65.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 143.8862,
#              'latitude': -36.6292,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 65.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 143.195,
#              'latitude': -35.7937,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 141.3013,
#              'latitude': -36.9142,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 57.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 143.8908,
#              'latitude': -36.6306,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 142.9087,
#              'latitude': -37.3586,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 59.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 143.7501,
#              'latitude': -36.9524,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 60.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 141.8567,
#              'latitude': -37.0643,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 50.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 141.4047,
#              'latitude': -36.2403,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 64.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 141.0877,
#              'latitude': -36.6776,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 56.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 143.1197,
#              'latitude': -37.7929,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 64.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 143.1153,
#              'latitude': -37.7972,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 64.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 4, 12, 0, 0),
#  'hotspot': {'longitude': 143.8206,
#              'latitude': -37.3656,
#              'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#              'confidence': 59.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 4, 13, 0, 0),
#  'hotspot': {'longitude': 143.3048,
#              'latitude': -37.8865,
#              'datetime': datetime.datetime(2022, 4, 13, 4, 36, 30),
#              'confidence': 68.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 4, 13, 0, 0),
#  'hotspot': {'longitude': 143.2121,
#              'latitude': -37.5687,
#              'datetime': datetime.datetime(2022, 4, 13, 4, 36, 20),
#              'confidence': 62.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 4, 13, 0, 0),
#  'hotspot': {'longitude': 143.0108,
#              'latitude': -37.7359,
# ...
#
# {'date': datetime.datetime(2022, 10, 1, 0, 0),
#  'hotspot': {'longitude': 148.113,
#              'latitude': -37.46,
#              'datetime': datetime.datetime(2022, 10, 1, 4, 10, 28),
#              'confidence': 64.0,
#              'surface_temperature': 52.0}}
#
# {'date': datetime.datetime(2022, 10, 2, 0, 0),
#  'hotspot': {'longitude': 148.1,
#              'latitude': -37.466,
#              'datetime': datetime.datetime(2022, 10, 2, 23, 44, 31),
#              'confidence': 50.0,
#              'surface_temperature': 29.0}}
#
# {'date': datetime.datetime(2022, 10, 2, 0, 0),
#  'hotspot': {'longitude': 148.134,
#              'latitude': -37.475,
#              'datetime': datetime.datetime(2022, 10, 2, 4, 53, 10),
#              'confidence': 59.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 10, 2, 0, 0),
#  'hotspot': {'longitude': 148.11,
#              'latitude': -37.456,
#              'datetime': datetime.datetime(2022, 10, 2, 0, 39, 34),
#              'confidence': 68.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 10, 3, 0, 0),
#  'hotspot': {'longitude': 148.109,
#              'latitude': -37.461,
#              'datetime': datetime.datetime(2022, 10, 3, 15, 1, 44),
#              'confidence': 69.0,
#              'surface_temperature': 33.0}}
#
# {'date': datetime.datetime(2022, 10, 3, 0, 0),
#  'hotspot': {'longitude': 141.176,
#              'latitude': -37.236,
#              'datetime': datetime.datetime(2022, 10, 3, 3, 58, 28),
#              'confidence': 68.0,
#              'surface_temperature': 37.0}}
#
# {'date': datetime.datetime(2022, 10, 3, 0, 0),
#  'hotspot': {'longitude': 141.151,
#              'latitude': -37.227,
#              'datetime': datetime.datetime(2022, 10, 3, 3, 58, 28),
#              'confidence': 59.0,
#              'surface_temperature': 35.0}}
#
# {'date': datetime.datetime(2022, 10, 3, 0, 0),
#  'hotspot': {'longitude': 141.146,
#              'latitude': -37.227,
#              'datetime': datetime.datetime(2022, 10, 3, 1, 22, 44),
#              'confidence': 54.0,
#              'surface_temperature': 31.0}}
#
# {'date': datetime.datetime(2022, 10, 4, 0, 0),
#  'hotspot': {'longitude': 141.596,
#              'latitude': -36.418,
#              'datetime': datetime.datetime(2022, 10, 4, 4, 41, 36),
#              'confidence': 50.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 10, 16, 0, 0),
#  'hotspot': {'longitude': 144.39,
#              'latitude': -37.288,
#              'datetime': datetime.datetime(2022, 10, 16, 23, 56, 43),
#              'confidence': 62.0,
#              'surface_temperature': 36.0}}
#
# {'date': datetime.datetime(2022, 10, 17, 0, 0),
#  'hotspot': {'longitude': 142.479,
#              'latitude': -37.587,
#              'datetime': datetime.datetime(2022, 10, 17, 4, 10, 38),
#              'confidence': 58.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 10, 20, 0, 0),
#  'hotspot': {'longitude': 144.386,
#              'latitude': -37.296,
#              'datetime': datetime.datetime(2022, 10, 20, 0, 27, 12),
#              'confidence': 65.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 10, 21, 0, 0),
#  'hotspot': {'longitude': 143.772,
#              'latitude': -36.1,
#              'datetime': datetime.datetime(2022, 10, 21, 1, 9, 54),
#              'confidence': 65.0,
#              'surface_temperature': 35.0}}
#
# {'date': datetime.datetime(2022, 10, 26, 0, 0),
#  'hotspot': {'longitude': 143.568,
#              'latitude': -36.156,
#              'datetime': datetime.datetime(2022, 10, 26, 4, 4, 53),
#              'confidence': 67.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 10, 26, 0, 0),
#  'hotspot': {'longitude': 143.578,
#              'latitude': -36.152,
#              'datetime': datetime.datetime(2022, 10, 26, 4, 4, 53),
#              'confidence': 69.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 10, 27, 0, 0),
#  'hotspot': {'longitude': 144.168,
#              'latitude': -36.748,
#              'datetime': datetime.datetime(2022, 10, 27, 4, 47, 31),
#              'confidence': 62.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 11, 8, 0, 0),
#  'hotspot': {'longitude': 141.129,
#              'latitude': -36.538,
#              'datetime': datetime.datetime(2022, 11, 8, 5, 12, 8),
#              'confidence': 60.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 11, 9, 0, 0),
#  'hotspot': {'longitude': 145.179,
#              'latitude': -36.759,
#              'datetime': datetime.datetime(2022, 11, 9, 4, 16, 56),
#              'confidence': 68.0,
#              'surface_temperature': 52.0}}
#
# {'date': datetime.datetime(2022, 11, 9, 0, 0),
#  'hotspot': {'longitude': 145.19,
#              'latitude': -36.758,
#              'datetime': datetime.datetime(2022, 11, 9, 4, 16, 56),
#              'confidence': 62.0,
#              'surface_temperature': 51.0}}
#
# {'date': datetime.datetime(2022, 11, 9, 0, 0),
#  'hotspot': {'longitude': 142.154,
#              'latitude': -37.719,
#              'datetime': datetime.datetime(2022, 11, 9, 4, 16, 46),
#              'confidence': 63.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 11, 11, 0, 0),
#  'hotspot': {'longitude': 143.286,
#              'latitude': -36.943,
#              'datetime': datetime.datetime(2022, 11, 11, 15, 8),
#              'confidence': 51.0,
#              'surface_temperature': 29.0}}
#
# {'date': datetime.datetime(2022, 11, 12, 0, 0),
#  'hotspot': {'longitude': 143.282,
#              'latitude': -36.942,
#              'datetime': datetime.datetime(2022, 11, 12, 4, 47, 32),
#              'confidence': 63.0,
#              'surface_temperature': 53.0}}
#
# {'date': datetime.datetime(2022, 11, 12, 0, 0),
#  'hotspot': {'longitude': 144.174,
#              'latitude': -37.864,
#              'datetime': datetime.datetime(2022, 11, 12, 4, 47, 16),
#              'confidence': 58.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 11, 12, 0, 0),
#  'hotspot': {'longitude': 146.272,
#              'latitude': -38.912,
#              'datetime': datetime.datetime(2022, 11, 12, 4, 46, 53),
#              'confidence': 56.0,
#              'surface_temperature': 48.0}}
#
# {'date': datetime.datetime(2022, 11, 12, 0, 0),
#  'hotspot': {'longitude': 143.292,
#              'latitude': -36.942,
#              'datetime': datetime.datetime(2022, 11, 12, 0, 33, 15),
#              'confidence': 67.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 11, 13, 0, 0),
#  'hotspot': {'longitude': 143.918,
#              'latitude': -37.954,
#              'datetime': datetime.datetime(2022, 11, 13, 3, 52, 8),
#              'confidence': 64.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 11, 13, 0, 0),
#  'hotspot': {'longitude': 143.841,
#              'latitude': -38.167,
#              'datetime': datetime.datetime(2022, 11, 13, 1, 16, 38),
#              'confidence': 51.0,
#              'surface_temperature': 38.0}}
#
# {'date': datetime.datetime(2022, 11, 13, 0, 0),
#  'hotspot': {'longitude': 143.803,
#              'latitude': -38.16,
#              'datetime': datetime.datetime(2022, 11, 13, 1, 16, 37),
#              'confidence': 62.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 11, 14, 0, 0),
#  'hotspot': {'longitude': 143.493,
#              'latitude': -38.527,
#              'datetime': datetime.datetime(2022, 11, 14, 0, 21, 26),
#              'confidence': 64.0,
#              'surface_temperature': 45.0}}
#
# {'date': datetime.datetime(2022, 11, 14, 0, 0),
#  'hotspot': {'longitude': 143.375,
#              'latitude': -37.332,
#              'datetime': datetime.datetime(2022, 11, 14, 0, 21, 7),
#              'confidence': 64.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 11, 23, 0, 0),
#  'hotspot': {'longitude': 143.183,
#              'latitude': -38.141,
#              'datetime': datetime.datetime(2022, 11, 23, 0, 15, 12),
#              'confidence': 68.0,
#              'surface_temperature': 46.0}}
#
# {'date': datetime.datetime(2022, 11, 23, 0, 0),
#  'hotspot': {'longitude': 144.972,
#              'latitude': -36.952,
#              'datetime': datetime.datetime(2022, 11, 23, 0, 14, 47),
#              'confidence': 63.0,
#              'surface_temperature': 60.0}}
#
# {'date': datetime.datetime(2022, 11, 28, 0, 0),
#  'hotspot': {'longitude': 148.297,
#              'latitude': -37.749,
#              'datetime': datetime.datetime(2022, 11, 28, 0, 33, 14),
#              'confidence': 50.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 11, 29, 0, 0),
#  'hotspot': {'longitude': 149.277,
#              'latitude': -37.611,
#              'datetime': datetime.datetime(2022, 11, 29, 13, 17, 24),
#              'confidence': 53.0,
#              'surface_temperature': 38.0}}
#
# {'date': datetime.datetime(2022, 11, 29, 0, 0),
#  'hotspot': {'longitude': 149.308,
#              'latitude': -37.605,
#              'datetime': datetime.datetime(2022, 11, 29, 13, 17, 24),
#              'confidence': 68.0,
#              'surface_temperature': 43.0}}
#
# {'date': datetime.datetime(2022, 11, 29, 0, 0),
#  'hotspot': {'longitude': 142.121,
#              'latitude': -34.282,
#              'datetime': datetime.datetime(2022, 11, 29, 3, 53, 16),
#              'confidence': 52.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 11, 29, 0, 0),
#  'hotspot': {'longitude': 149.326,
#              'latitude': -37.605,
#              'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#              'confidence': 64.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 149.303,
#              'latitude': -37.635,
#              'datetime': datetime.datetime(2022, 11, 30, 23, 25, 57),
#              'confidence': 52.0,
#              'surface_temperature': 47.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 149.31,
#              'latitude': -37.59,
#              'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#              'confidence': 51.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 149.264,
#              'latitude': -37.633,
#              'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#              'confidence': 64.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 149.331,
#              'latitude': -37.58,
#              'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#              'confidence': 69.0,
#              'surface_temperature': 35.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 149.334,
#              'latitude': -37.38,
#              'datetime': datetime.datetime(2022, 11, 30, 15, 38, 32),
#              'confidence': 61.0,
#              'surface_temperature': 31.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 149.295,
#              'latitude': -37.602,
#              'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#              'confidence': 62.0,
#              'surface_temperature': 33.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 149.29,
#              'latitude': -37.598,
#              'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#              'confidence': 64.0,
#              'surface_temperature': 32.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 149.279,
#              'latitude': -37.61,
#              'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#              'confidence': 69.0,
#              'surface_temperature': 48.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 146.288,
#              'latitude': -37.637,
#              'datetime': datetime.datetime(2022, 11, 30, 0, 21),
#              'confidence': 60.0,
#              'surface_temperature': 42.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 149.297,
#              'latitude': -37.6,
#              'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#              'confidence': 69.0,
#              'surface_temperature': 50.0}}
#
# {'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': {'longitude': 149.341,
#              'latitude': -37.382,
#              'datetime': datetime.datetime(2022, 11, 30, 0, 20, 49),
#              'confidence': 64.0,
#              'surface_temperature': 41.0}}
#
# {'date': datetime.datetime(2022, 12, 8, 0, 0),
#  'hotspot': {'longitude': 146.159,
#              'latitude': -36.291,
#              'datetime': datetime.datetime(2022, 12, 8, 13, 11, 43),
#              'confidence': 56.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 12, 10, 0, 0),
#  'hotspot': {'longitude': 144.005,
#              'latitude': -37.987,
#              'datetime': datetime.datetime(2022, 12, 10, 0, 57, 59),
#              'confidence': 50.0,
#              'surface_temperature': 38.0}}
#
# {'date': datetime.datetime(2022, 12, 10, 0, 0),
#  'hotspot': {'longitude': 141.712,
#              'latitude': -34.289,
#              'datetime': datetime.datetime(2022, 12, 10, 0, 56, 57),
#              'confidence': 67.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 12, 12, 0, 0),
#  'hotspot': {'longitude': 145.25,
#              'latitude': -37.903,
#              'datetime': datetime.datetime(2022, 12, 12, 0, 45, 38),
#              'confidence': 53.0,
#              'surface_temperature': 44.0}}
#
# {'date': datetime.datetime(2022, 12, 15, 0, 0),
#  'hotspot': {'longitude': 149.323,
#              'latitude': -37.623,
#              'datetime': datetime.datetime(2022, 12, 15, 13, 17, 17),
#              'confidence': 51.0,
#              'surface_temperature': 38.0}}
#
# {'date': datetime.datetime(2022, 12, 15, 0, 0),
#  'hotspot': {'longitude': 142.986,
#              'latitude': -38.038,
#              'datetime': datetime.datetime(2022, 12, 15, 1, 16, 23),
#              'confidence': 65.0,
#              'surface_temperature': 40.0}}
#
# {'date': datetime.datetime(2022, 12, 16, 0, 0),
#  'hotspot': {'longitude': 149.332,
#              'latitude': -37.624,
#              'datetime': datetime.datetime(2022, 12, 16, 15, 38, 39),
#              'confidence': 69.0,
#              'surface_temperature': 33.0}}
#
# {'date': datetime.datetime(2022, 12, 16, 0, 0),
#  'hotspot': {'longitude': 142.323,
#              'latitude': -37.82,
#              'datetime': datetime.datetime(2022, 12, 16, 4, 35, 15),
#              'confidence': 62.0,
#              'surface_temperature': 54.0}}
#
# {'date': datetime.datetime(2022, 12, 16, 0, 0),
#  'hotspot': {'longitude': 149.346,
#              'latitude': -37.644,
#              'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#              'confidence': 59.0,
#              'surface_temperature': 55.0}}
#
# {'date': datetime.datetime(2022, 12, 16, 0, 0),
#  'hotspot': {'longitude': 144.201,
#              'latitude': -38.046,
#              'datetime': datetime.datetime(2022, 12, 16, 0, 21, 11),
#              'confidence': 60.0,
#              'surface_temperature': 48.0}}
#
# {'date': datetime.datetime(2022, 12, 16, 0, 0),
#  'hotspot': {'longitude': 149.335,
#              'latitude': -37.63,
#              'datetime': datetime.datetime(2022, 12, 16, 0, 20, 53),
#              'confidence': 53.0,
#              'surface_temperature': 57.0}}
#
# {'date': datetime.datetime(2022, 12, 24, 0, 0),
#  'hotspot': {'longitude': 142.282,
#              'latitude': -35.646,
#              'datetime': datetime.datetime(2022, 12, 24, 13, 12, 1),
#              'confidence': 65.0,
#              'surface_temperature': 32.0}}
#
# {'date': datetime.datetime(2022, 12, 27, 0, 0),
#  'hotspot': {'longitude': 143.307,
#              'latitude': -35.554,
#              'datetime': datetime.datetime(2022, 12, 27, 0, 2, 15),
#              'confidence': 67.0,
#              'surface_temperature': 53.0}}

# %% [markdown]
# h) Find the average surface temperature (°C) for each day. You are required to only display average surface temperature (°C) and the date in the output.

# %%
response = fire_collection.aggregate([
    {'$unwind':'$hotspot'},
    {'$group':{'_id':'$date', 'avg_surface_temperature':{'$avg':'$hotspot.surface_temperature'}}},
    {'$project':{'_id':0, 'date': '$_id', 'avg_surface_temperature':1}},
    {'$sort':{'date':1}}
])

# %%
print_response(response)
# Out:
# {'avg_surface_temperature': 60.5, 'date': datetime.datetime(2022, 3, 6, 0, 0)}
#
# {'avg_surface_temperature': 64.0, 'date': datetime.datetime(2022, 3, 7, 0, 0)}
#
# {'avg_surface_temperature': 51.5, 'date': datetime.datetime(2022, 3, 8, 0, 0)}
#
# {'avg_surface_temperature': 46.666666666666664,
#  'date': datetime.datetime(2022, 3, 9, 0, 0)}
#
# {'avg_surface_temperature': 69.375,
#  'date': datetime.datetime(2022, 3, 10, 0, 0)}
#
# {'avg_surface_temperature': 88.2, 'date': datetime.datetime(2022, 3, 12, 0, 0)}
#
# {'avg_surface_temperature': 38.5, 'date': datetime.datetime(2022, 3, 13, 0, 0)}
#
# {'avg_surface_temperature': 65.6, 'date': datetime.datetime(2022, 3, 14, 0, 0)}
#
# {'avg_surface_temperature': 46.0, 'date': datetime.datetime(2022, 3, 15, 0, 0)}
#
# {'avg_surface_temperature': 59.5, 'date': datetime.datetime(2022, 3, 17, 0, 0)}
#
# {'avg_surface_temperature': 79.33333333333333,
#  'date': datetime.datetime(2022, 3, 18, 0, 0)}
#
# {'avg_surface_temperature': 65.57142857142857,
#  'date': datetime.datetime(2022, 3, 19, 0, 0)}
#
# {'avg_surface_temperature': 49.0, 'date': datetime.datetime(2022, 3, 24, 0, 0)}
#
# {'avg_surface_temperature': 66.0, 'date': datetime.datetime(2022, 3, 25, 0, 0)}
#
# {'avg_surface_temperature': 56.88235294117647,
#  'date': datetime.datetime(2022, 3, 26, 0, 0)}
#
# {'avg_surface_temperature': 60.925925925925924,
#  'date': datetime.datetime(2022, 3, 28, 0, 0)}
#
# {'avg_surface_temperature': 51.0, 'date': datetime.datetime(2022, 3, 29, 0, 0)}
#
# {'avg_surface_temperature': 48.72727272727273,
#  'date': datetime.datetime(2022, 3, 31, 0, 0)}
#
# {'avg_surface_temperature': 46.714285714285715,
#  'date': datetime.datetime(2022, 4, 1, 0, 0)}
#
# {'avg_surface_temperature': 45.2, 'date': datetime.datetime(2022, 4, 2, 0, 0)}
#
# {'avg_surface_temperature': 58.44444444444444,
#  'date': datetime.datetime(2022, 4, 3, 0, 0)}
#
# {'avg_surface_temperature': 62.57303370786517,
#  'date': datetime.datetime(2022, 4, 4, 0, 0)}
#
# {'avg_surface_temperature': 53.142857142857146,
#  'date': datetime.datetime(2022, 4, 5, 0, 0)}
#
# {'avg_surface_temperature': 61.71186440677966,
#  'date': datetime.datetime(2022, 4, 6, 0, 0)}
#
# {'avg_surface_temperature': 50.69230769230769,
#  'date': datetime.datetime(2022, 4, 7, 0, 0)}
#
# {'avg_surface_temperature': 60.75, 'date': datetime.datetime(2022, 4, 8, 0, 0)}
#
# {'avg_surface_temperature': 46.291666666666664,
#  'date': datetime.datetime(2022, 4, 11, 0, 0)}
#
# {'avg_surface_temperature': 52.69565217391305,
#  'date': datetime.datetime(2022, 4, 12, 0, 0)}
#
# {'avg_surface_temperature': 58.57983193277311,
#  'date': datetime.datetime(2022, 4, 13, 0, 0)}
#
# {'avg_surface_temperature': 61.94444444444444,
#  'date': datetime.datetime(2022, 4, 14, 0, 0)}
#
# {'avg_surface_temperature': 59.57971014492754,
#  'date': datetime.datetime(2022, 4, 15, 0, 0)}
#
# {'avg_surface_temperature': 48.72222222222222,
#  'date': datetime.datetime(2022, 4, 16, 0, 0)}
#
# {'avg_surface_temperature': 50.921052631578945,
#  'date': datetime.datetime(2022, 4, 17, 0, 0)}
#
# {'avg_surface_temperature': 53.36615384615384,
#  'date': datetime.datetime(2022, 4, 18, 0, 0)}
#
# {'avg_surface_temperature': 54.16, 'date': datetime.datetime(2022, 4, 19, 0, 0)}
#
# {'avg_surface_temperature': 56.58064516129032,
#  'date': datetime.datetime(2022, 4, 20, 0, 0)}
#
# {'avg_surface_temperature': 54.5, 'date': datetime.datetime(2022, 4, 22, 0, 0)}
#
# {'avg_surface_temperature': 53.89473684210526,
#  'date': datetime.datetime(2022, 4, 23, 0, 0)}
#
# {'avg_surface_temperature': 59.375,
#  'date': datetime.datetime(2022, 4, 24, 0, 0)}
#
# {'avg_surface_temperature': 48.666666666666664,
#  'date': datetime.datetime(2022, 4, 25, 0, 0)}
#
# {'avg_surface_temperature': 34.0, 'date': datetime.datetime(2022, 4, 26, 0, 0)}
#
# {'avg_surface_temperature': 63.0, 'date': datetime.datetime(2022, 4, 29, 0, 0)}
#
# {'avg_surface_temperature': 68.4, 'date': datetime.datetime(2022, 5, 1, 0, 0)}
#
# {'avg_surface_temperature': 55.6, 'date': datetime.datetime(2022, 5, 2, 0, 0)}
#
# {'avg_surface_temperature': 56.796875,
#  'date': datetime.datetime(2022, 5, 3, 0, 0)}
#
# {'avg_surface_temperature': 56.80740740740741,
#  'date': datetime.datetime(2022, 5, 4, 0, 0)}
#
# {'avg_surface_temperature': 51.70967741935484,
#  'date': datetime.datetime(2022, 5, 5, 0, 0)}
#
# {'avg_surface_temperature': 57.529411764705884,
#  'date': datetime.datetime(2022, 5, 6, 0, 0)}
#
# {'avg_surface_temperature': 50.333333333333336,
#  'date': datetime.datetime(2022, 5, 7, 0, 0)}
#
# {'avg_surface_temperature': 56.291666666666664,
#  'date': datetime.datetime(2022, 5, 8, 0, 0)}
#
# {'avg_surface_temperature': 42.46153846153846,
#  'date': datetime.datetime(2022, 5, 9, 0, 0)}
#
# {'avg_surface_temperature': 52.86842105263158,
#  'date': datetime.datetime(2022, 5, 10, 0, 0)}
#
# {'avg_surface_temperature': 59.36842105263158,
#  'date': datetime.datetime(2022, 5, 11, 0, 0)}
#
# {'avg_surface_temperature': 51.5, 'date': datetime.datetime(2022, 5, 12, 0, 0)}
#
# {'avg_surface_temperature': 58.611111111111114,
#  'date': datetime.datetime(2022, 5, 13, 0, 0)}
#
# {'avg_surface_temperature': 49.0, 'date': datetime.datetime(2022, 5, 14, 0, 0)}
#
# {'avg_surface_temperature': 53.950980392156865,
#  'date': datetime.datetime(2022, 5, 15, 0, 0)}
#
# {'avg_surface_temperature': 39.666666666666664,
#  'date': datetime.datetime(2022, 5, 16, 0, 0)}
#
# {'avg_surface_temperature': 52.0, 'date': datetime.datetime(2022, 5, 17, 0, 0)}
#
# {'avg_surface_temperature': 44.142857142857146,
#  'date': datetime.datetime(2022, 5, 18, 0, 0)}
#
# {'avg_surface_temperature': 54.484848484848484,
#  'date': datetime.datetime(2022, 5, 22, 0, 0)}
#
# {'avg_surface_temperature': 51.2, 'date': datetime.datetime(2022, 5, 23, 0, 0)}
#
# {'avg_surface_temperature': 40.333333333333336,
#  'date': datetime.datetime(2022, 5, 24, 0, 0)}
#
# {'avg_surface_temperature': 49.5, 'date': datetime.datetime(2022, 5, 26, 0, 0)}
#
# {'avg_surface_temperature': 54.0, 'date': datetime.datetime(2022, 6, 1, 0, 0)}
#
# {'avg_surface_temperature': 47.72727272727273,
#  'date': datetime.datetime(2022, 6, 2, 0, 0)}
#
# {'avg_surface_temperature': 47.0, 'date': datetime.datetime(2022, 6, 3, 0, 0)}
#
# {'avg_surface_temperature': 52.22222222222222,
#  'date': datetime.datetime(2022, 6, 4, 0, 0)}
#
# {'avg_surface_temperature': 51.857142857142854,
#  'date': datetime.datetime(2022, 6, 7, 0, 0)}
#
# {'avg_surface_temperature': 49.0, 'date': datetime.datetime(2022, 6, 9, 0, 0)}
#
# {'avg_surface_temperature': 41.5, 'date': datetime.datetime(2022, 6, 11, 0, 0)}
#
# {'avg_surface_temperature': 41.0, 'date': datetime.datetime(2022, 6, 13, 0, 0)}
#
# {'avg_surface_temperature': 53.25, 'date': datetime.datetime(2022, 6, 14, 0, 0)}
#
# {'avg_surface_temperature': 42.5, 'date': datetime.datetime(2022, 6, 16, 0, 0)}
#
# {'avg_surface_temperature': 42.0, 'date': datetime.datetime(2022, 6, 18, 0, 0)}
#
# {'avg_surface_temperature': 71.16666666666667,
#  'date': datetime.datetime(2022, 6, 20, 0, 0)}
#
# {'avg_surface_temperature': 46.0, 'date': datetime.datetime(2022, 6, 22, 0, 0)}
#
# {'avg_surface_temperature': 44.333333333333336,
#  'date': datetime.datetime(2022, 6, 30, 0, 0)}
#
# {'avg_surface_temperature': 30.5, 'date': datetime.datetime(2022, 7, 1, 0, 0)}
#
# {'avg_surface_temperature': 43.5, 'date': datetime.datetime(2022, 7, 2, 0, 0)}
#
# {'avg_surface_temperature': 40.0, 'date': datetime.datetime(2022, 7, 4, 0, 0)}
#
# {'avg_surface_temperature': 45.0, 'date': datetime.datetime(2022, 7, 5, 0, 0)}
#
# {'avg_surface_temperature': 56.0, 'date': datetime.datetime(2022, 7, 6, 0, 0)}
#
# {'avg_surface_temperature': 41.5, 'date': datetime.datetime(2022, 7, 14, 0, 0)}
#
# {'avg_surface_temperature': 48.0, 'date': datetime.datetime(2022, 7, 29, 0, 0)}
#
# {'avg_surface_temperature': 47.0, 'date': datetime.datetime(2022, 7, 31, 0, 0)}
#
# {'avg_surface_temperature': 58.0, 'date': datetime.datetime(2022, 8, 1, 0, 0)}
#
# {'avg_surface_temperature': 63.5, 'date': datetime.datetime(2022, 8, 2, 0, 0)}
#
# {'avg_surface_temperature': 40.0, 'date': datetime.datetime(2022, 8, 5, 0, 0)}
#
# {'avg_surface_temperature': 63.0, 'date': datetime.datetime(2022, 8, 10, 0, 0)}
#
# {'avg_surface_temperature': 49.0, 'date': datetime.datetime(2022, 8, 13, 0, 0)}
#
# {'avg_surface_temperature': 40.8, 'date': datetime.datetime(2022, 8, 14, 0, 0)}
#
# {'avg_surface_temperature': 56.5, 'date': datetime.datetime(2022, 9, 10, 0, 0)}
#
# {'avg_surface_temperature': 63.6, 'date': datetime.datetime(2022, 9, 20, 0, 0)}
#
# {'avg_surface_temperature': 40.5, 'date': datetime.datetime(2022, 9, 21, 0, 0)}
#
# {'avg_surface_temperature': 45.0, 'date': datetime.datetime(2022, 9, 22, 0, 0)}
#
# {'avg_surface_temperature': 52.73913043478261,
#  'date': datetime.datetime(2022, 9, 23, 0, 0)}
#
# {'avg_surface_temperature': 53.57142857142857,
#  'date': datetime.datetime(2022, 9, 24, 0, 0)}
#
# {'avg_surface_temperature': 33.0, 'date': datetime.datetime(2022, 9, 26, 0, 0)}
#
# {'avg_surface_temperature': 49.714285714285715,
#  'date': datetime.datetime(2022, 9, 27, 0, 0)}
#
# {'avg_surface_temperature': 43.0, 'date': datetime.datetime(2022, 9, 29, 0, 0)}
#
# {'avg_surface_temperature': 48.25, 'date': datetime.datetime(2022, 10, 1, 0, 0)}
#
# {'avg_surface_temperature': 43.57142857142857,
#  'date': datetime.datetime(2022, 10, 2, 0, 0)}
#
# {'avg_surface_temperature': 50.0, 'date': datetime.datetime(2022, 10, 3, 0, 0)}
#
# {'avg_surface_temperature': 49.0, 'date': datetime.datetime(2022, 10, 4, 0, 0)}
#
# {'avg_surface_temperature': 44.0, 'date': datetime.datetime(2022, 10, 6, 0, 0)}
#
# {'avg_surface_temperature': 42.0, 'date': datetime.datetime(2022, 10, 7, 0, 0)}
#
# {'avg_surface_temperature': 41.0, 'date': datetime.datetime(2022, 10, 8, 0, 0)}
#
# {'avg_surface_temperature': 44.0, 'date': datetime.datetime(2022, 10, 9, 0, 0)}
#
# {'avg_surface_temperature': 53.333333333333336,
#  'date': datetime.datetime(2022, 10, 10, 0, 0)}
#
# {'avg_surface_temperature': 72.66666666666667,
#  'date': datetime.datetime(2022, 10, 15, 0, 0)}
#
# {'avg_surface_temperature': 36.0, 'date': datetime.datetime(2022, 10, 16, 0, 0)}
#
# {'avg_surface_temperature': 51.6, 'date': datetime.datetime(2022, 10, 17, 0, 0)}
#
# {'avg_surface_temperature': 52.166666666666664,
#  'date': datetime.datetime(2022, 10, 18, 0, 0)}
#
# {'avg_surface_temperature': 50.0, 'date': datetime.datetime(2022, 10, 20, 0, 0)}
#
# {'avg_surface_temperature': 51.25,
#  'date': datetime.datetime(2022, 10, 21, 0, 0)}
#
# {'avg_surface_temperature': 38.0, 'date': datetime.datetime(2022, 10, 23, 0, 0)}
#
# {'avg_surface_temperature': 44.6, 'date': datetime.datetime(2022, 10, 26, 0, 0)}
#
# {'avg_surface_temperature': 50.4, 'date': datetime.datetime(2022, 10, 27, 0, 0)}
#
# {'avg_surface_temperature': 56.0, 'date': datetime.datetime(2022, 10, 28, 0, 0)}
#
# {'avg_surface_temperature': 58.5, 'date': datetime.datetime(2022, 11, 5, 0, 0)}
#
# {'avg_surface_temperature': 45.5, 'date': datetime.datetime(2022, 11, 8, 0, 0)}
#
# {'avg_surface_temperature': 61.3, 'date': datetime.datetime(2022, 11, 9, 0, 0)}
#
# {'avg_surface_temperature': 46.25,
#  'date': datetime.datetime(2022, 11, 11, 0, 0)}
#
# {'avg_surface_temperature': 53.0, 'date': datetime.datetime(2022, 11, 12, 0, 0)}
#
# {'avg_surface_temperature': 47.0, 'date': datetime.datetime(2022, 11, 13, 0, 0)}
#
# {'avg_surface_temperature': 52.0, 'date': datetime.datetime(2022, 11, 14, 0, 0)}
#
# {'avg_surface_temperature': 59.0, 'date': datetime.datetime(2022, 11, 21, 0, 0)}
#
# {'avg_surface_temperature': 61.5, 'date': datetime.datetime(2022, 11, 22, 0, 0)}
#
# {'avg_surface_temperature': 58.8, 'date': datetime.datetime(2022, 11, 23, 0, 0)}
#
# {'avg_surface_temperature': 42.0, 'date': datetime.datetime(2022, 11, 28, 0, 0)}
#
# {'avg_surface_temperature': 60.625,
#  'date': datetime.datetime(2022, 11, 29, 0, 0)}
#
# {'avg_surface_temperature': 52.41935483870968,
#  'date': datetime.datetime(2022, 11, 30, 0, 0)}
#
# {'avg_surface_temperature': 50.6, 'date': datetime.datetime(2022, 12, 8, 0, 0)}
#
# {'avg_surface_temperature': 58.25, 'date': datetime.datetime(2022, 12, 9, 0, 0)}
#
# {'avg_surface_temperature': 46.0, 'date': datetime.datetime(2022, 12, 10, 0, 0)}
#
# {'avg_surface_temperature': 44.0, 'date': datetime.datetime(2022, 12, 12, 0, 0)}
#
# {'avg_surface_temperature': 60.0, 'date': datetime.datetime(2022, 12, 13, 0, 0)}
#
# {'avg_surface_temperature': 70.0, 'date': datetime.datetime(2022, 12, 14, 0, 0)}
#
# {'avg_surface_temperature': 39.0, 'date': datetime.datetime(2022, 12, 15, 0, 0)}
#
# {'avg_surface_temperature': 57.8, 'date': datetime.datetime(2022, 12, 16, 0, 0)}
#
# {'avg_surface_temperature': 46.0, 'date': datetime.datetime(2022, 12, 21, 0, 0)}
#
# {'avg_surface_temperature': 32.0, 'date': datetime.datetime(2022, 12, 24, 0, 0)}
#
# {'avg_surface_temperature': 54.0, 'date': datetime.datetime(2022, 12, 25, 0, 0)}
#
# {'avg_surface_temperature': 62.75,
#  'date': datetime.datetime(2022, 12, 27, 0, 0)}

# %% [markdown]
# i) Find the top 10 records with the lowest GHI.

# %%
response = fire_collection.find().sort('GHI', -1).limit(10)

# %%
print_response(response)
# Out:
# {'_id': ObjectId('64809ea999470914613d9ed0'),
#  'station': 948700,
#  'date': datetime.datetime(2022, 1, 7, 0, 0),
#  'hotspot': [],
#  'air_temperature': 32.0,
#  'relative_humidity': 54.1,
#  'windspeed_knots': 12.8,
#  'max_wind_speed': 19.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 265.0}
#
# {'_id': ObjectId('64809eaa99470914613da007'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 11, 14, 0, 0),
#  'hotspot': [{'longitude': 144.175,
#               'latitude': -37.862,
#               'datetime': datetime.datetime(2022, 11, 14, 4, 35, 4),
#               'confidence': 87.0,
#               'surface_temperature': 65.0},
#              {'longitude': 143.493,
#               'latitude': -38.527,
#               'datetime': datetime.datetime(2022, 11, 14, 0, 21, 26),
#               'confidence': 64.0,
#               'surface_temperature': 45.0},
#              {'longitude': 143.375,
#               'latitude': -37.332,
#               'datetime': datetime.datetime(2022, 11, 14, 0, 21, 7),
#               'confidence': 64.0,
#               'surface_temperature': 46.0}],
#  'air_temperature': 28.0,
#  'relative_humidity': 48.3,
#  'windspeed_knots': 11.9,
#  'max_wind_speed': 22.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 243.0}
#
# {'_id': ObjectId('64809eaa99470914613da024'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 12, 13, 0, 0),
#  'hotspot': [{'longitude': 147.172,
#               'latitude': -38.231,
#               'datetime': datetime.datetime(2022, 12, 13, 4, 4, 19),
#               'confidence': 83.0,
#               'surface_temperature': 60.0}],
#  'air_temperature': 28.0,
#  'relative_humidity': 49.9,
#  'windspeed_knots': 11.0,
#  'max_wind_speed': 19.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 240.0}
#
# {'_id': ObjectId('64809ea999470914613d9ef0'),
#  'station': 948700,
#  'date': datetime.datetime(2022, 2, 8, 0, 0),
#  'hotspot': [],
#  'air_temperature': 31.0,
#  'relative_humidity': 61.9,
#  'windspeed_knots': 14.1,
#  'max_wind_speed': 23.9,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 239.0}
#
# {'_id': ObjectId('64809eaa99470914613da016'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 11, 29, 0, 0),
#  'hotspot': [{'longitude': 149.277,
#               'latitude': -37.611,
#               'datetime': datetime.datetime(2022, 11, 29, 13, 17, 24),
#               'confidence': 53.0,
#               'surface_temperature': 38.0},
#              {'longitude': 149.292,
#               'latitude': -37.608,
#               'datetime': datetime.datetime(2022, 11, 29, 13, 17, 24),
#               'confidence': 100.0,
#               'surface_temperature': 55.0},
#              {'longitude': 149.308,
#               'latitude': -37.605,
#               'datetime': datetime.datetime(2022, 11, 29, 13, 17, 24),
#               'confidence': 68.0,
#               'surface_temperature': 43.0},
#              {'longitude': 142.121,
#               'latitude': -34.282,
#               'datetime': datetime.datetime(2022, 11, 29, 3, 53, 16),
#               'confidence': 52.0,
#               'surface_temperature': 54.0},
#              {'longitude': 149.312,
#               'latitude': -37.606,
#               'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#               'confidence': 100.0,
#               'surface_temperature': 87.0},
#              {'longitude': 149.326,
#               'latitude': -37.605,
#               'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#               'confidence': 64.0,
#               'surface_temperature': 44.0},
#              {'longitude': 149.307,
#               'latitude': -37.61,
#               'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#               'confidence': 97.0,
#               'surface_temperature': 80.0},
#              {'longitude': 149.32,
#               'latitude': -37.609,
#               'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#               'confidence': 99.0,
#               'surface_temperature': 84.0}],
#  'air_temperature': 28.0,
#  'relative_humidity': 56.7,
#  'windspeed_knots': 9.3,
#  'max_wind_speed': 16.9,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 227.0}
#
# {'_id': ObjectId('64809ea999470914613d9f13'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 3, 15, 0, 0),
#  'hotspot': [{'longitude': 147.0196,
#               'latitude': -37.4108,
#               'datetime': datetime.datetime(2022, 3, 15, 5, 2),
#               'confidence': 76.0,
#               'surface_temperature': 50.0},
#              {'longitude': 147.0117,
#               'latitude': -37.4058,
#               'datetime': datetime.datetime(2022, 3, 15, 4, 59, 10),
#               'confidence': 74.0,
#               'surface_temperature': 48.0},
#              {'longitude': 147.0233,
#               'latitude': -37.4075,
#               'datetime': datetime.datetime(2022, 3, 15, 0, 42, 50),
#               'confidence': 52.0,
#               'surface_temperature': 43.0},
#              {'longitude': 148.1281,
#               'latitude': -37.0228,
#               'datetime': datetime.datetime(2022, 3, 15, 0, 42, 50),
#               'confidence': 66.0,
#               'surface_temperature': 43.0},
#              {'longitude': 148.2055,
#               'latitude': -37.002,
#               'datetime': datetime.datetime(2022, 3, 15, 0, 42, 40),
#               'confidence': 51.0,
#               'surface_temperature': 44.0},
#              {'longitude': 148.1561,
#               'latitude': -37.0249,
#               'datetime': datetime.datetime(2022, 3, 15, 0, 38, 10),
#               'confidence': 75.0,
#               'surface_temperature': 49.0},
#              {'longitude': 147.0489,
#               'latitude': -37.4098,
#               'datetime': datetime.datetime(2022, 3, 15, 0, 37, 20),
#               'confidence': 70.0,
#               'surface_temperature': 45.0}],
#  'air_temperature': 28.0,
#  'relative_humidity': 58.4,
#  'windspeed_knots': 11.9,
#  'max_wind_speed': 18.1,
#  'precipitation_flag': 'G',
#  'precipitation': 0.04,
#  'GHI': 223.0}
#
# {'_id': ObjectId('64809eaa99470914613da032'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 12, 27, 0, 0),
#  'hotspot': [{'longitude': 145.051,
#               'latitude': -37.966,
#               'datetime': datetime.datetime(2022, 12, 27, 4, 16, 51),
#               'confidence': 78.0,
#               'surface_temperature': 68.0},
#              {'longitude': 143.311,
#               'latitude': -35.541,
#               'datetime': datetime.datetime(2022, 12, 27, 0, 2, 15),
#               'confidence': 82.0,
#               'surface_temperature': 63.0},
#              {'longitude': 143.307,
#               'latitude': -35.554,
#               'datetime': datetime.datetime(2022, 12, 27, 0, 2, 15),
#               'confidence': 67.0,
#               'surface_temperature': 53.0},
#              {'longitude': 143.316,
#               'latitude': -35.543,
#               'datetime': datetime.datetime(2022, 12, 27, 0, 2, 14),
#               'confidence': 86.0,
#               'surface_temperature': 67.0}],
#  'air_temperature': 28.0,
#  'relative_humidity': 58.3,
#  'windspeed_knots': 9.3,
#  'max_wind_speed': 15.9,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 223.0}
#
# {'_id': ObjectId('64809eaa99470914613d9fec'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 10, 18, 0, 0),
#  'hotspot': [{'longitude': 144.392,
#               'latitude': -37.287,
#               'datetime': datetime.datetime(2022, 10, 18, 0, 39, 27),
#               'confidence': 79.0,
#               'surface_temperature': 49.0},
#              {'longitude': 144.377,
#               'latitude': -37.295,
#               'datetime': datetime.datetime(2022, 10, 18, 0, 39, 27),
#               'confidence': 75.0,
#               'surface_temperature': 46.0},
#              {'longitude': 141.063,
#               'latitude': -35.364,
#               'datetime': datetime.datetime(2022, 10, 18, 0, 39, 3),
#               'confidence': 72.0,
#               'surface_temperature': 54.0},
#              {'longitude': 145.606,
#               'latitude': -35.89,
#               'datetime': datetime.datetime(2022, 10, 18, 0, 39, 2),
#               'confidence': 84.0,
#               'surface_temperature': 59.0},
#              {'longitude': 145.614,
#               'latitude': -35.889,
#               'datetime': datetime.datetime(2022, 10, 18, 0, 39, 2),
#               'confidence': 82.0,
#               'surface_temperature': 56.0},
#              {'longitude': 145.62,
#               'latitude': -35.892,
#               'datetime': datetime.datetime(2022, 10, 18, 0, 39, 2),
#               'confidence': 71.0,
#               'surface_temperature': 49.0}],
#  'air_temperature': 26.0,
#  'relative_humidity': 52.2,
#  'windspeed_knots': 13.7,
#  'max_wind_speed': 16.9,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 219.0}
#
# {'_id': ObjectId('64809ea999470914613d9eec'),
#  'station': 948700,
#  'date': datetime.datetime(2022, 2, 4, 0, 0),
#  'hotspot': [],
#  'air_temperature': 26.0,
#  'relative_humidity': 53.7,
#  'windspeed_knots': 8.7,
#  'max_wind_speed': 15.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 216.0}
#
# {'_id': ObjectId('64809eaa99470914613da00e'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 11, 21, 0, 0),
#  'hotspot': [{'longitude': 144.693,
#               'latitude': -37.758,
#               'datetime': datetime.datetime(2022, 11, 21, 0, 27, 21),
#               'confidence': 85.0,
#               'surface_temperature': 59.0}],
#  'air_temperature': 24.0,
#  'relative_humidity': 51.8,
#  'windspeed_knots': 7.9,
#  'max_wind_speed': 15.0,
#  'precipitation_flag': 'I',
#  'precipitation': 0.0,
#  'GHI': 203.0}

# %% [markdown]
# j) Find the records with a 24-hour precipitation recorded between 0.20 to 0.35

# %%
response = fire_collection.find(
    {'precipitation_flag':'G', 'precipitation':{'$gte':0.2, '$lte':0.35}}
)

# %%
print_response(response)
# Out:
# {'_id': ObjectId('64809ea999470914613d9ed6'),
#  'station': 948700,
#  'date': datetime.datetime(2022, 1, 13, 0, 0),
#  'hotspot': [],
#  'air_temperature': 19.0,
#  'relative_humidity': 54.1,
#  'windspeed_knots': 11.2,
#  'max_wind_speed': 18.1,
#  'precipitation_flag': 'G',
#  'precipitation': 0.31,
#  'GHI': 157.0}
#
# {'_id': ObjectId('64809ea999470914613d9f21'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 3, 29, 0, 0),
#  'hotspot': [{'longitude': 141.6325,
#               'latitude': -34.2648,
#               'datetime': datetime.datetime(2022, 3, 29, 0, 48, 40),
#               'confidence': 69.0,
#               'surface_temperature': 51.0}],
#  'air_temperature': 17.0,
#  'relative_humidity': 49.9,
#  'windspeed_knots': 12.2,
#  'max_wind_speed': 21.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.24,
#  'GHI': 146.0}
#
# {'_id': ObjectId('64809ea999470914613d9f37'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 4, 20, 0, 0),
#  'hotspot': [{'longitude': 145.1536,
#               'latitude': -36.8871,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 44, 20),
#               'confidence': 84.0,
#               'surface_temperature': 58.0},
#              {'longitude': 146.673,
#               'latitude': -38.4685,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 36),
#               'confidence': 59.0,
#               'surface_temperature': 40.0},
#              {'longitude': 145.1252,
#               'latitude': -36.8922,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 34, 10),
#               'confidence': 60.0,
#               'surface_temperature': 40.0},
#              {'longitude': 147.94,
#               'latitude': -37.769,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 34, 10),
#               'confidence': 93.0,
#               'surface_temperature': 72.0},
#              {'longitude': 146.0784,
#               'latitude': -36.0799,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 33, 40),
#               'confidence': 77.0,
#               'surface_temperature': 50.0},
#              {'longitude': 146.0621,
#               'latitude': -36.0829,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 33, 20),
#               'confidence': 88.0,
#               'surface_temperature': 63.0},
#              {'longitude': 146.3606,
#               'latitude': -36.1303,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 32, 50),
#               'confidence': 90.0,
#               'surface_temperature': 67.0},
#              {'longitude': 147.9169,
#               'latitude': -37.7615,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 32, 50),
#               'confidence': 67.0,
#               'surface_temperature': 45.0},
#              {'longitude': 145.1409,
#               'latitude': -36.8079,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#               'confidence': 63.0,
#               'surface_temperature': 42.0},
#              {'longitude': 147.9284,
#               'latitude': -37.7783,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#               'confidence': 85.0,
#               'surface_temperature': 60.0},
#              {'longitude': 145.1679,
#               'latitude': -36.8846,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#               'confidence': 79.0,
#               'surface_temperature': 52.0},
#              {'longitude': 149.1736,
#               'latitude': -37.2341,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#               'confidence': 80.0,
#               'surface_temperature': 53.0},
#              {'longitude': 147.5603,
#               'latitude': -36.9189,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#               'confidence': 63.0,
#               'surface_temperature': 52.0},
#              {'longitude': 146.351,
#               'latitude': -36.1345,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#               'confidence': 98.0,
#               'surface_temperature': 84.0},
#              {'longitude': 147.5559,
#               'latitude': -36.9246,
#               'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#               'confidence': 87.0,
#               'surface_temperature': 62.0},
#              {'longitude': 145.9096,
#               'latitude': -36.085,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 19),
#               'confidence': 64.0,
#               'surface_temperature': 42.0},
#              {'longitude': 143.9398,
#               'latitude': -38.1301,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 18, 40),
#               'confidence': 88.0,
#               'surface_temperature': 63.0},
#              {'longitude': 145.5499,
#               'latitude': -37.7087,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 18, 20),
#               'confidence': 69.0,
#               'surface_temperature': 45.0},
#              {'longitude': 145.2081,
#               'latitude': -36.5865,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 18, 20),
#               'confidence': 100.0,
#               'surface_temperature': 111.0},
#              {'longitude': 144.0381,
#               'latitude': -36.8702,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 17, 10),
#               'confidence': 73.0,
#               'surface_temperature': 47.0},
#              {'longitude': 145.6666,
#               'latitude': -36.1586,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 17, 10),
#               'confidence': 99.0,
#               'surface_temperature': 85.0},
#              {'longitude': 143.8194,
#               'latitude': -37.8672,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 16, 50),
#               'confidence': 74.0,
#               'surface_temperature': 48.0},
#              {'longitude': 145.206,
#               'latitude': -36.5956,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 15, 30),
#               'confidence': 78.0,
#               'surface_temperature': 51.0},
#              {'longitude': 148.8134,
#               'latitude': -37.2197,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 14, 20),
#               'confidence': 77.0,
#               'surface_temperature': 50.0},
#              {'longitude': 145.1968,
#               'latitude': -36.5847,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 14, 10),
#               'confidence': 96.0,
#               'surface_temperature': 78.0},
#              {'longitude': 145.5519,
#               'latitude': -37.6997,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 13, 40),
#               'confidence': 89.0,
#               'surface_temperature': 64.0},
#              {'longitude': 146.1845,
#               'latitude': -37.932,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 13, 30),
#               'confidence': 61.0,
#               'surface_temperature': 50.0},
#              {'longitude': 144.2957,
#               'latitude': -36.6407,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 13, 10),
#               'confidence': 76.0,
#               'surface_temperature': 50.0},
#              {'longitude': 145.6554,
#               'latitude': -36.1569,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 13),
#               'confidence': 63.0,
#               'surface_temperature': 41.0},
#              {'longitude': 144.3033,
#               'latitude': -36.6363,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 13),
#               'confidence': 54.0,
#               'surface_temperature': 40.0},
#              {'longitude': 148.8262,
#               'latitude': -37.2212,
#               'datetime': datetime.datetime(2022, 4, 20, 0, 12, 50),
#               'confidence': 76.0,
#               'surface_temperature': 49.0}],
#  'air_temperature': 20.0,
#  'relative_humidity': 53.5,
#  'windspeed_knots': 7.2,
#  'max_wind_speed': 15.9,
#  'precipitation_flag': 'G',
#  'precipitation': 0.31,
#  'GHI': 166.0}
#
# {'_id': ObjectId('64809ea999470914613d9f3d'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 4, 26, 0, 0),
#  'hotspot': [{'longitude': 146.7819,
#               'latitude': -36.5511,
#               'datetime': datetime.datetime(2022, 4, 26, 13, 26, 10),
#               'confidence': 56.0,
#               'surface_temperature': 34.0}],
#  'air_temperature': 11.0,
#  'relative_humidity': 40.8,
#  'windspeed_knots': 12.2,
#  'max_wind_speed': 20.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.24,
#  'GHI': 102.0}
#
# {'_id': ObjectId('64809ea999470914613d9f5c'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 5, 27, 0, 0),
#  'hotspot': [],
#  'air_temperature': 14.0,
#  'relative_humidity': 48.1,
#  'windspeed_knots': 13.7,
#  'max_wind_speed': 19.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.35,
#  'GHI': 122.0}
#
# {'_id': ObjectId('64809ea999470914613d9f5f'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 5, 30, 0, 0),
#  'hotspot': [],
#  'air_temperature': 8.0,
#  'relative_humidity': 41.6,
#  'windspeed_knots': 8.3,
#  'max_wind_speed': 15.9,
#  'precipitation_flag': 'G',
#  'precipitation': 0.24,
#  'GHI': 73.0}
#
# {'_id': ObjectId('64809ea999470914613d9f81'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 7, 3, 0, 0),
#  'hotspot': [],
#  'air_temperature': 11.0,
#  'relative_humidity': 45.1,
#  'windspeed_knots': 11.5,
#  'max_wind_speed': 18.1,
#  'precipitation_flag': 'G',
#  'precipitation': 0.2,
#  'GHI': 98.0}
#
# {'_id': ObjectId('64809eaa99470914613d9f99'),
#  'station': 948701,
#  'date': datetime.datetime(2022, 7, 27, 0, 0),
#  'hotspot': [],
#  'air_temperature': 11.0,
#  'relative_humidity': 43.5,
#  'windspeed_knots': 13.1,
#  'max_wind_speed': 21.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.24,
#  'GHI': 99.0}
#
# {'_id': ObjectId('64809eaa99470914613d9fa3'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 8, 6, 0, 0),
#  'hotspot': [],
#  'air_temperature': 9.0,
#  'relative_humidity': 41.1,
#  'windspeed_knots': 12.7,
#  'max_wind_speed': 19.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.24,
#  'GHI': 83.0}
#
# {'_id': ObjectId('64809eaa99470914613d9fb7'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 8, 26, 0, 0),
#  'hotspot': [],
#  'air_temperature': 11.0,
#  'relative_humidity': 39.7,
#  'windspeed_knots': 11.8,
#  'max_wind_speed': 19.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.28,
#  'GHI': 102.0}
#
# {'_id': ObjectId('64809eaa99470914613d9fc1'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 9, 5, 0, 0),
#  'hotspot': [],
#  'air_temperature': 8.0,
#  'relative_humidity': 38.6,
#  'windspeed_knots': 12.8,
#  'max_wind_speed': 18.1,
#  'precipitation_flag': 'G',
#  'precipitation': 0.31,
#  'GHI': 75.0}
#
# {'_id': ObjectId('64809eaa99470914613d9fc3'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 9, 7, 0, 0),
#  'hotspot': [],
#  'air_temperature': 10.0,
#  'relative_humidity': 43.6,
#  'windspeed_knots': 9.7,
#  'max_wind_speed': 14.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.2,
#  'GHI': 90.0}
#
# {'_id': ObjectId('64809eaa99470914613d9fcb'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 9, 15, 0, 0),
#  'hotspot': [],
#  'air_temperature': 11.0,
#  'relative_humidity': 46.2,
#  'windspeed_knots': 10.5,
#  'max_wind_speed': 15.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.28,
#  'GHI': 97.0}
#
# {'_id': ObjectId('64809eaa99470914613d9fdf'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 10, 5, 0, 0),
#  'hotspot': [],
#  'air_temperature': 12.0,
#  'relative_humidity': 47.5,
#  'windspeed_knots': 15.0,
#  'max_wind_speed': 18.1,
#  'precipitation_flag': 'G',
#  'precipitation': 0.2,
#  'GHI': 105.0}
#
# {'_id': ObjectId('64809eaa99470914613d9ff7'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 10, 29, 0, 0),
#  'hotspot': [],
#  'air_temperature': 17.0,
#  'relative_humidity': 44.9,
#  'windspeed_knots': 16.1,
#  'max_wind_speed': 27.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.24,
#  'GHI': 152.0}
#
# {'_id': ObjectId('64809eaa99470914613d9ff8'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 10, 30, 0, 0),
#  'hotspot': [],
#  'air_temperature': 11.0,
#  'relative_humidity': 43.2,
#  'windspeed_knots': 8.1,
#  'max_wind_speed': 14.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.2,
#  'GHI': 100.0}
#
# {'_id': ObjectId('64809eaa99470914613da009'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 11, 16, 0, 0),
#  'hotspot': [],
#  'air_temperature': 18.0,
#  'relative_humidity': 61.5,
#  'windspeed_knots': 5.5,
#  'max_wind_speed': 11.1,
#  'precipitation_flag': 'G',
#  'precipitation': 0.28,
#  'GHI': 140.0}
#
# {'_id': ObjectId('64809eaa99470914613da00a'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 11, 17, 0, 0),
#  'hotspot': [],
#  'air_temperature': 19.0,
#  'relative_humidity': 58.7,
#  'windspeed_knots': 5.5,
#  'max_wind_speed': 12.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.28,
#  'GHI': 151.0}
#
# {'_id': ObjectId('64809eaa99470914613da017'),
#  'station': 948702,
#  'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspot': [{'longitude': 149.303,
#               'latitude': -37.635,
#               'datetime': datetime.datetime(2022, 11, 30, 23, 25, 57),
#               'confidence': 52.0,
#               'surface_temperature': 47.0},
#              {'longitude': 149.33,
#               'latitude': -37.591,
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#               'confidence': 100.0,
#               'surface_temperature': 53.0},
#              {'longitude': 149.31,
#               'latitude': -37.59,
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#               'confidence': 51.0,
#               'surface_temperature': 42.0},
#              {'longitude': 149.264,
#               'latitude': -37.633,
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#               'confidence': 64.0,
#               'surface_temperature': 42.0},
#              {'longitude': 149.336,
#               'latitude': -37.585,
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#               'confidence': 100.0,
#               'surface_temperature': 54.0},
#              {'longitude': 149.331,
#               'latitude': -37.58,
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#               'confidence': 69.0,
#               'surface_temperature': 35.0},
#              {'longitude': 149.316,
#               'latitude': -37.583,
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#               'confidence': 100.0,
#               'surface_temperature': 49.0},
#              {'longitude': 149.334,
#               'latitude': -37.38,
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 32),
#               'confidence': 61.0,
#               'surface_temperature': 31.0},
#              {'longitude': 149.295,
#               'latitude': -37.602,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'confidence': 62.0,
#               'surface_temperature': 33.0},
#              {'longitude': 149.29,
#               'latitude': -37.598,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'confidence': 64.0,
#               'surface_temperature': 32.0},
#              {'longitude': 149.319,
#               'latitude': -37.596,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'confidence': 84.0,
#               'surface_temperature': 38.0},
#              {'longitude': 149.232,
#               'latitude': -37.63,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'confidence': 81.0,
#               'surface_temperature': 42.0},
#              {'longitude': 149.233,
#               'latitude': -37.644,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'confidence': 100.0,
#               'surface_temperature': 55.0},
#              {'longitude': 149.263,
#               'latitude': -37.642,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'confidence': 100.0,
#               'surface_temperature': 65.0},
#              {'longitude': 149.237,
#               'latitude': -37.634,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 14),
#               'confidence': 100.0,
#               'surface_temperature': 71.0},
#              {'longitude': 149.336,
#               'latitude': -37.384,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 35),
#               'confidence': 84.0,
#               'surface_temperature': 59.0},
#              {'longitude': 149.311,
#               'latitude': -37.389,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 35),
#               'confidence': 73.0,
#               'surface_temperature': 50.0},
#              {'longitude': 149.302,
#               'latitude': -37.605,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#               'confidence': 98.0,
#               'surface_temperature': 83.0},
#              {'longitude': 149.261,
#               'latitude': -37.627,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#               'confidence': 81.0,
#               'surface_temperature': 57.0},
#              {'longitude': 149.284,
#               'latitude': -37.623,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#               'confidence': 84.0,
#               'surface_temperature': 61.0},
#              {'longitude': 149.325,
#               'latitude': -37.6,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#               'confidence': 99.0,
#               'surface_temperature': 86.0},
#              {'longitude': 149.279,
#               'latitude': -37.61,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#               'confidence': 69.0,
#               'surface_temperature': 48.0},
#              {'longitude': 146.288,
#               'latitude': -37.637,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 21),
#               'confidence': 60.0,
#               'surface_temperature': 42.0},
#              {'longitude': 149.282,
#               'latitude': -37.608,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'confidence': 83.0,
#               'surface_temperature': 58.0},
#              {'longitude': 149.294,
#               'latitude': -37.62,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'confidence': 87.0,
#               'surface_temperature': 63.0},
#              {'longitude': 149.281,
#               'latitude': -37.618,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'confidence': 95.0,
#               'surface_temperature': 76.0},
#              {'longitude': 149.296,
#               'latitude': -37.61,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'confidence': 81.0,
#               'surface_temperature': 56.0},
#              {'longitude': 149.324,
#               'latitude': -37.603,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'confidence': 73.0,
#               'surface_temperature': 51.0},
#              {'longitude': 149.311,
#               'latitude': -37.602,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'confidence': 81.0,
#               'surface_temperature': 55.0},
#              {'longitude': 149.297,
#               'latitude': -37.6,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'confidence': 69.0,
#               'surface_temperature': 50.0},
#              {'longitude': 149.341,
#               'latitude': -37.382,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 49),
#               'confidence': 64.0,
#               'surface_temperature': 41.0}],
#  'air_temperature': 26.0,
#  'relative_humidity': 61.0,
#  'windspeed_knots': 9.3,
#  'max_wind_speed': 15.0,
#  'precipitation_flag': 'G',
#  'precipitation': 0.2,
#  'GHI': 202.0}

# %% [markdown]
# # Task 2.3 - Indexing

# %% [markdown]
# From Task 2, the most frequently used attributes are date, surface_temperature, and confidence. Since date is the most used attributes in query, we should use it as an index to increase performance of queries using it. On the other hand, surface_temperature and confidence are attributes within the embedded array, and it will take much longer to find them as we have to go through all the document and the embedded documents. So we will also use surface_temperature and confidence as index.

# %%
# Drop index
fire_collection.drop_indexes()

# %%
# -1 is descending
response = fire_collection.create_index([
    ('date', -1), # Latest data play more importance
    ('hotspot.surface_temperature', -1),  # Hotter surface temperature is more important
    ('hotspot.confidence', -1) # Higher confidence is more important
], name="climate_index")

# %%
fire_collection.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]},
#  'climate_index': {'v': 2,
#   'key': [('date', -1),
#    ('hotspot.surface_temperature', -1),
#    ('hotspot.confidence', -1)]}}
